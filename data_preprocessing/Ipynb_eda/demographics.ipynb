# %%
#!/usr/bin/python3
# -*-coding:utf-8
'''
Created on Fri Dec 1 22:22:35 2017

@author: Ray

'''
import time
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import utils # written by author
from glob import glob
from datetime import datetime, timedelta
import multiprocessing as mp
import gc # for automatic releasing memory

##################################################
# Load members and
##################################################
members = pd.read_csv('../../input/members_v3.csv')

#==============================================================================
print('reduce memory')
#==============================================================================
utils.reduce_memory(members)


##################################################
# Gender
##################################################
def gender(x):
    if x == 'female':
        return 0
    elif x == 'male':
        return 1
    else:
        return 2 # 2:代表missing values
members['gender'] = members.gender.apply(gender)
##################################################
# city
##################################################
members['city'] = members.city.apply(lambda x: int(x) if pd.notnull(x) else 2) # 把City-NaN當作2

##################################################
#registered_via
##################################################
registered_via_dict = {k:v+1 for v,k in enumerate(members['registered_via'].unique().tolist())}
'''
key: orginal registered_via
{-1: 18,
 1: 15,
 2: 10,
 3: 4,
 4: 6,
 5: 9,
 6: 13,
 7: 2,
 8: 12,
 9: 3,
 10: 17,
 11: 1,
 13: 7,
 14: 14,
 16: 5,
 17: 8,
 18: 16,
 19: 11}
 # 18代表nan
'''
members['registered_via'] = members.registered_via.apply(lambda x: registered_via_dict[x]) # 把NaN當作2

##################################################
# Birthd Date Cleaning
##################################################

# missing value (12%) and outliers(about 49%)
members['bd'] = members.bd.apply(lambda x: -99999 if float(x)<=1 else x )
members['bd'] = members.bd.apply(lambda x: -99999 if float(x)>=100 else x )
members['bd'] = members.bd.apply(lambda x: int(x) if pd.notnull(x) else -99999 )

tmp_bd_for_filling = members[members.bd != -99999] # using mean of bd as filling of missing values and outliers
mean_bd = int(tmp_bd_for_filling.bd.mean())
del tmp_bd_for_filling

members['bd'] = members.bd.apply(lambda x: mean_bd if x == -99999 else x )
# Out:
# reduce memory
# 100%|██████████| 6/6 [00:00<00:00, 1147.66it/s]

# %%
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769473 entries, 0 to 6769472
# Data columns (total 6 columns):
# msno                      object
# city                      int64
# bd                        int64
# gender                    int64
# registered_via            int64
# registration_init_time    int32
# dtypes: int32(1), int64(4), object(1)
# memory usage: 284.1+ MB

# %%
#==============================================================================
print('reduce memory')
#==============================================================================
utils.reduce_memory(members)
# Out:
# reduce memory
# 100%|██████████| 6/6 [00:00<00:00, 628.41it/s]

# %%
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769473 entries, 0 to 6769472
# Data columns (total 6 columns):
# msno                      object
# city                      int8
# bd                        int8
# gender                    int8
# registered_via            int8
# registration_init_time    int32
# dtypes: int32(1), int8(4), object(1)
# memory usage: 103.3+ MB

# %%
members['is_registerd_via_4'] = members.registered_via.apply(lambda x: 1 if x == 6 else 0)
members['is_registerd_via_7'] = members.registered_via.apply(lambda x: 1 if x == 2 else 0)

# %%
members.head(n = 20)
# Out:
#                                             msno  city  bd  gender  \
# 0   Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1  29       2
# 1   +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1  29       2
# 2   cV358ssn7a0f7jZOwGNWS07wCKVqxyiImJUX6xcIwKw=     1  29       2
# 3   9bzDeJP6sQodK73K5CBlJ6fgIQzPeLnRl0p5B77XP+g=     1  29       2
# 4   WFLY3s7z4EZsieHCt63XrsdtfTEmJ+2PnnKLH5GY4Tk=     6  32       0
# 5   yLkV2gbZ4GLFwqTOXLVHz0VGrMYcgBGgKZ3kj9RiYu8=     4  30       1
# 6   jNCGK78YkTyId3H3wFavcBLDmz7pfqlvCfUKf4G1Lw4=     1  29       2
# 7   WH5Jq4mgtfUFXh2yz+HrcTXKS4Oess4k4W3qKolAeb0=     5  34       1
# 8   tKmbR4X5VXjHmxERrckawEMZ4znVy1lAQIR1vV5rdNk=     5  19       1
# 9   I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13  63       1
# 10  OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1  29       2
# 11  dCvvBHlaOAqgkAcv36IZ9twaCyH0Z9om0wEiKn13B3o=    22  18       1
# 12  6bra2AiVV8SGlm7R6mp97Ot5jU9FBH2/8JaRk0iaKco=     4  34       0
# 13  4De1jAxNRABoyRBDZ82U0yEmzYkqeOugRGVNIf92Xb8=     4  28       0
# 14  iOzdu4IHbJxhB5CPpiQsZcGdptCm7OLwWm1Ci6oHLSE=    12  29       0
# 15  hZia/3iyvtThD1kv6ozRjRj8T0CAz0+zUFxs3e27wo8=     1  29       2
# 16  QlDflP89J5KChheo2sbtH++SSDY/hUDj54gkgdfE76U=     1  29       2
# 17  fOpj0ApSXk1NVODvC5db5Tvm/1G6exXxgTiCwTqvQn0=    13  31       0
# 18  GsPgdrXoV6688/0RFAwjKxQUpBB28JxK/Nx45kEpH60=     1  29       2
# 19  QHHKGOY5yLrGdR8WYb0JtdJTP36Ii1QP3QTXxjEpGLk=     5  19       0
#
#     registered_via  registration_init_time  is_registerd_via_4  \
# 0                1                20110911                   0
# 1                2                20110914                   0
# 2                1                20110915                   0
# 3                1                20110915                   0
# 4                3                20110915                   0
# 5                3                20110916                   0
# 6                2                20110916                   0
# 7                3                20110916                   0
# 8                3                20110917                   0
# 9                3                20110918                   0
# 10               2                20110918                   0
# 11               3                20110919                   0
# 12               3                20110919                   0
# 13               3                20110920                   0
# 14               3                20110922                   0
# 15               3                20110922                   0
# 16               3                20110922                   0
# 17               2                20110923                   0
# 18               2                20110924                   0
# 19               3                20110925                   0
#
#     is_registerd_via_7
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0
# 5                    0
# 6                    1
# 7                    0
# 8                    0
# 9                    0
# 10                   1
# 11                   0
# 12                   0
# 13                   0
# 14                   0
# 15                   0
# 16                   0
# 17                   1
# 18                   1
# 19                   0

# %%
def bd_zone(x):
	if  x <= 18:
		return 1 # 大學生以下
	elif 18 < x <= 22:
		return 2 # 大學生
	elif 22 < x < 35:
		return 3 # 上班族
	else:
		return 4 # 35以上lol
		
members['bd_zone'] = members.bd.apply(bd_zone)

# %%
members
# Out:
#                                                  msno  city  bd  gender  \
# 0        Rb9UwLQTrxzBVwCB6+bCcSQWZ9JiNLC9dXtM1oEsZA8=     1  29       2
# 1        +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1  29       2
# 6769472  isBt+JlgvZRNy6lxVr5vvuJ4lD00ofTaKyJ+uRnGcPg=     1  29       2
#
#          registered_via  registration_init_time  is_registerd_via_4  \
# 0                     1                20110911                   0
# 1                     2                20110914                   0
# 2                     1                20110915                   0
# 3                     1                20110915                   0
# 4                     3                20110915                   0
# 5                     3                20110916                   0
# 6                     2                20110916                   0
# 7                     3                20110916                   0
# 8                     3                20110917                   0
# 9                     3                20110918                   0
# 10                    2                20110918                   0
# 11                    3                20110919                   0
# 12                    3                20110919                   0
# 13                    3                20110920                   0
# 14                    3                20110922                   0
# 15                    3                20110922                   0
# 16                    3                20110922                   0
# 17                    2                20110923                   0
# 18                    2                20110924                   0
# 19                    3                20110925                   0
# 20                    3                20110925                   0
# 21                    3                20110925                   0
# 22                    3                20110925                   0
# 23                    3                20110926                   0
# 24                    3                20110926                   0
# 25                    3                20110926                   0
# 26                    2                20110927                   0
# 27                    3                20110927                   0
# 28                    2                20110928                   0
# 29                    3                20110928                   0
# ...                 ...                     ...                 ...
# 6769443               2                20151020                   0
# 6769444               6                20151020                   1
# 6769445               6                20151020                   1
# 6769446               6                20151020                   1
# 6769447               6                20151020                   1
# 6769448               6                20151020                   1
# 6769449               6                20151020                   1
# 6769450               6                20151020                   1
# 6769451               6                20151020                   1
# 6769452               6                20151020                   1
# 6769453               6                20151020                   1
# 6769454               6                20151020                   1
# 6769455               6                20151020                   1
# 6769456               6                20151020                   1
# 6769457               6                20151020                   1
# 6769458               3                20151020                   0
# 6769459               6                20151020                   1
# 6769460               6                20151020                   1
# 6769461               6                20151020                   1
# 6769462               3                20151020                   0
# 6769463               6                20151020                   1
# 6769464               6                20151020                   1
# 6769465               2                20151020                   0
# 6769466               2                20151020                   0
# 6769467               2                20151020                   0
# 6769468               2                20151020                   0
# 6769469               2                20151020                   0
# 6769470               6                20151020                   1
# 6769471               6                20151020                   1
# 6769472               6                20151021                   1
#
#          is_registerd_via_7  bd_zone
# 0                         0        3
# 1                         1        3
# 2                         0        3
# 3                         0        3
# 4                         0        3
# 5                         0        3
# 6                         1        3
# 7                         0        3
# 8                         0        2
# 9                         0        4
# 10                        1        3
# 11                        0        1
# 12                        0        3
# 13                        0        3
# 14                        0        3
# 15                        0        3
# 16                        0        3
# 17                        1        3
# 18                        1        3
# 19                        0        2
# 20                        0        2
# 21                        0        3
# 22                        0        2
# 23                        0        3
# 24                        0        2
# 25                        0        2
# 26                        1        3
# 27                        0        3
# 28                        1        4
# 29                        0        3
# ...                     ...      ...
# 6769443                   1        3
# 6769444                   0        3
# 6769445                   0        3
# 6769446                   0        3
# 6769447                   0        3
# 6769448                   0        2
# 6769449                   0        3
# 6769450                   0        3
# 6769451                   0        3
# 6769452                   0        2
# 6769453                   0        3
# 6769454                   0        3
# 6769455                   0        4
# 6769456                   0        3
# 6769457                   0        3
# 6769458                   0        3
# 6769459                   0        3
# 6769460                   0        3
# 6769461                   0        3
# 6769462                   0        3
# 6769463                   0        3
# 6769464                   0        3
# 6769465                   1        3
# 6769466                   1        3
# 6769467                   1        3
# 6769468                   1        3
# 6769469                   1        3
# 6769470                   0        3
# 6769471                   0        3
# 6769472                   0        3
#
# [6769473 rows x 9 columns]

# %%
members['is_living_in_city-21'] = members.city.apply(lambda x: 1 if x == 21 else 0)
members['is_living_in_city-2'] = members.city.apply(lambda x: 1 if x == 2 else 0)

# %%
members[members.city == 21]
# Out:
#                                                  msno  city  bd  gender  \
# 115      nv5dJzjDQjzpX1jiw9y4dF5vJ1w5dwj/BWN24y1Qudc=    21  20       0
# 276      Vf/uET/p/GayO3URHAzwCEdwIkW3x4vaA/XBL3CL1qM=    21  33       1
# 327      4RYyC9Ba0lfxI3xhN8JF0huBhymQts4vh72I6taMzsI=    21  18       0
# 400      qqMaRJurkfuSjLz+T3sigPgUexsEV5qPdnD7DIUs2wg=    21  29       0
# 530      O2Q9D3n3FbYyMdfj9O6cbyXLiP2R6c7VNVnA89EzuB4=    21  19       1
# 1388     dkcUFJdIPesnMJobPklGy5qD+TCsY4ezuGb3tbDO06k=    21  33       0
# 1428     6S5k10UBEzidKpUdJpwCVurEY3B3iRtodzSUT1z7nzY=    21  31       1
# 1494     dQvFM86vRVvPZItdmYKKMWM+HDqaxvaEYoBhEANS9c8=    21  29       1
# 1500     3kE7mL1nlSTuIhBmXPOrg1/qsTZKR3CSDM0owe/8yIU=    21  25       0
# 1607     IzbTmOOBTEs0VIqJ5cPESv+EpEL8faokkdSWNfk6fKI=    21  20       0
# 1629     VA0iOQfDNGQF+B+FGM/4p1qHvV49r7X6PtCwK9eaTq4=    21  23       1
# 1633     qfhOuRDfIn/BfTbe+DSdRByQ7iVUz9IDjh3CrTIgRN8=    21  29       0
# 1738     WFFTo95az3OyyKxJ+IAWyUECz4bxcFUAARizHywfwJs=    21  21       1
# 2141     YOabYP3rPkiUebkFnXcYC8SiDoTZb1igaqBaGOiCYVU=    21  26       1
# 2174     hMjTZjtxHcpsbR5N7aPhk+EOYWwmdiFR3niQJfpdhE4=    21  25       0
# 2195     0ckjwZp7AQ1wXiidG4sKFsbTqXBDDLftjDrse19JPIc=    21  31       0
# 2275     eTaBsRhhrwMtFfSeWz6WOHaYinhheFKBNxC9XpiqPC0=    21  28       0
# 2378     1FrrpjcDzpRNTLeFW6EI7YUxLR9eR9TYKL76DA1MI4Y=    21  21       1
# 2714     6EXu+bruD/hH75sJVX2Vcogrju8aCRzFzRHyoGhsJsU=    21  22       1
# 2779     nOYfzYaWhRJP5OxBiAyoSXukginvMUN1jnjOiIO8taQ=    21  26       1
# 2809     JRrtZZIWTCAFpTJYztJSsjXGRdn61xYAQhaMGVye8yw=    21  24       0
# 3021     iaXddrj8Y3l3REfV7Y+Jxt04j5Ud2qZTDw04WyAl0yI=    21  22       1
# 3237     c45Un4mURUfd838ecY2kZA1G6bPo2eiDNlg2+ODL894=    21  37       1
# 3262     ZxafVh5q3aDhKpOSEFENhGI0Jpfpg4Ms6nx9sWUClWg=    21  21       0
# 3367     gEHe3h02SOHktF1SsI2YtVYywvNQdHTpH808V2/zGzs=    21  23       1
# 3808     l1XMWr1XmYn0quakPSBS8uU15zNQKqxu+nK3ncqUTUg=    21  18       0
# 3262                      0        2                     1
# 3367                      0        3                     1
# 3808                      0        1                     1
# 4151                      0        3                     1
# 4199                      1        3                     1
# 4240                      0        2                     1
# 4404                      0        4                     1
# ...                     ...      ...                   ...
# 6764014                   0        1                     1
# 6764018                   0        3                     1
# 6764092                   0        1                     1
# 6764173                   0        2                     1
# 6764421                   0        3                     1
# 6764427                   0        3                     1
# 6764495                   1        3                     1
# 6765240                   0        3                     1
# 6765258                   0        1                     1
# 6765279                   0        3                     1
# 6765298                   1        3                     1
# 6765399                   0        2                     1
# 6765489                   0        2                     1
# 6765498                   0        3                     1
# 6765599                   0        2                     1
# 6765645                   0        3                     1
# 6766515                   0        3                     1
# 6766949                   0        3                     1
# 6767117                   0        4                     1
# 6767269                   0        3                     1
# 6767322                   0        3                     1
# 6767504                   0        4                     1
# 6767560                   0        4                     1
# 6767611                   0        3                     1
# 6767952                   0        3                     1
# 6768029                   0        4                     1
# 6768253                   0        1                     1
# 6768706                   0        3                     1
# 6768864                   0        2                     1
# 6769100                   0        2                     1
#
#          is_living_in_city-2
# 115                        0
# 276                        0
# 327                        0
# 400                        0
# 530                        0
# 1388                       0
# 1428                       0
# 1494                       0
# 1500                       0
# 1607                       0
# 1629                       0
# 1633                       0
# 1738                       0
# 2141                       0
# 2174                       0
# 2195                       0
# 2275                       0
# 2378                       0
# 2714                       0
# 2779                       0
# 2809                       0
# 3021                       0
# 3237                       0
# 3262                       0
# 3367                       0
# 3808                       0
# 4151                       0
# 4199                       0
# 4240                       0
# 4404                       0
# ...                      ...
# 6764014                    0
# 6764018                    0
# 6764092                    0
# 6764173                    0
# 6764421                    0
# 6764427                    0
# 6764495                    0
# 6765240                    0
# 6765258                    0
# 6765279                    0
# 6765298                    0
# 6765399                    0
# 6765489                    0
# 6765498                    0
# 6765599                    0
# 6765645                    0
# 6766515                    0
# 6766949                    0
# 6767117                    0
# 6767269                    0
# 6767322                    0
# 6767504                    0
# 6767560                    0
# 6767611                    0
# 6767952                    0
# 6768029                    0
# 6768253                    0
# 6768706                    0
# 6768864                    0
# 6769100                    0
#
# [30837 rows x 11 columns]

# %%
def city_zone(x):
	if x in set([2,1,20,16,17,17]):
		return 1 # 最不容易流失的city_zone
	elif x in set([11,13,7,18,14,9]):
		return 2 
	elif x in set([10,5,22,6,15,12]):
		return 3 
	else:
		return 4 # 最容易流失的city_zone

# %%
members['city_zone'] = members.city.apply(city_zone)

# %%
set([2,1,20,16,17,17])
# Out:
# {1, 2, 16, 17, 20}

# %%
#==============================================================================
print('reduce memory')
#==============================================================================
utils.reduce_memory(members)
gc.collect()
# Out:
# reduce memory
# 100%|██████████| 12/12 [00:00<00:00, 492.11it/s]
# 0

# %%
members.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6769473 entries, 0 to 6769472
# Data columns (total 12 columns):
# msno                      object
# city                      int8
# bd                        int8
# gender                    int8
# registered_via            int8
# registration_init_time    int32
# is_registerd_via_4        int8
# is_registerd_via_7        int8
# bd_zone                   int8
# is_living_in_city-21      int8
# is_living_in_city-2       int8
# city_zone                 int8
# dtypes: int32(1), int8(10), object(1)
# memory usage: 142.0+ MB

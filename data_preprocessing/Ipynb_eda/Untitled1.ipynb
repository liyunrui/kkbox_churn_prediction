# %%
#!/usr/bin/python3
# -*-coding:utf-8

'''
Created on Fri Dec 1 01:08:45 2017

@author: Ray
'''

from tqdm import tqdm
import numpy as np
import os
from glob import glob
import pandas as pd
import gc

# %%
path = '../../feature/trainW-0'

# %%
ls = glob(path+'/*')
ls
# Out:
# ['../../feature/trainW-0/all',
#  '../../feature/trainW-0/amt_per_day.csv',
#  '../../feature/trainW-0/amt_per_day_n1.csv',
#  '../../feature/trainW-0/amt_per_day_n5.csv',
#  '../../feature/trainW-0/completed_songs_ratio.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_14.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_30.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_60.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_7.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_90.csv',
#  '../../feature/trainW-0/compressed_user_logs',
#  '../../feature/trainW-0/cp_value.csv',
#  '../../feature/trainW-0/cp_value_n1.csv',
#  '../../feature/trainW-0/cp_value_n5.csv',
#  '../../feature/trainW-0/date_diff.csv',
#  '../../feature/trainW-0/date_diff_during_t_14.csv',
#  '../../feature/trainW-0/date_diff_during_t_30.csv',
#  '../../feature/trainW-0/date_diff_during_t_60.csv',
# ...

# %%
ls.remove('../../feature/trainW-0/all')

# %%
ls.remove('../../feature/trainW-0/amt_per_day.csv')

# %%
ls
# Out:
# ['../../feature/trainW-0/amt_per_day_n1.csv',
#  '../../feature/trainW-0/amt_per_day_n5.csv',
#  '../../feature/trainW-0/completed_songs_ratio.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_14.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_30.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_60.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_7.csv',
#  '../../feature/trainW-0/completed_songs_ratio_during_t_90.csv',
#  '../../feature/trainW-0/compressed_user_logs',
#  '../../feature/trainW-0/cp_value.csv',
#  '../../feature/trainW-0/cp_value_n1.csv',
#  '../../feature/trainW-0/cp_value_n5.csv',
#  '../../feature/trainW-0/date_diff.csv',
#  '../../feature/trainW-0/date_diff_during_t_14.csv',
#  '../../feature/trainW-0/date_diff_during_t_30.csv',
#  '../../feature/trainW-0/date_diff_during_t_60.csv',
#  '../../feature/trainW-0/date_diff_during_t_7.csv',
#  '../../feature/trainW-0/date_diff_during_t_90.csv',
# ...

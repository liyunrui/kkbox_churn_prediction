# %%
def get_score_debug(self, fmap='', importance_type='weight'):
    """Get feature importance of each feature.
    Importance type can be defined as:
        'weight' - the number of times a feature is used to split the data across all trees.
        'gain' - the average gain of the feature when it is used in trees
        'cover' - the average coverage of the feature when it is used in trees
    Parameters
    ----------
    fmap: str (optional)
       The name of feature map file
    """

    if importance_type not in ['weight', 'gain', 'cover']:
        msg = "importance_type mismatch, got '{}', expected 'weight', 'gain', or 'cover'"
        raise ValueError(msg.format(importance_type))

    # if it's weight, then omap stores the number of missing values
    if importance_type == 'weight':
        # do a simpler tree dump to save time
        print ('what is fucking problem')
        trees = self.get_dump(fmap, with_stats=False) 
        # trees is list
        print ('trees',type(trees),len(trees),trees)
        fmap = {}
        for tree in trees:
            print ('tree',tree)
            for line in tree.split('\n'):
                print ('line',line)
                # look for the opening square bracket
                arr = line.split('[')
                print('arr',arr, len(arr)) # 包含feature id and leaf score
                # if no opening bracket (leaf node), ignore this line
                if len(arr) == 1:
                    continue

                # extract feature name from string between []
                fid = arr[1].split(']')[0].split('<')[0]
                print ('feature id', fid)
                if fid not in fmap:
                    # if the feature hasn't been seen yet
                    fmap[fid] = 1
                else:
                    fmap[fid] += 1

        return fmap

# %%
# use feature importance for feature selection
import pandas as pd
from numpy import loadtxt
from numpy import sort
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
from tqdm import tqdm
# load data
dataset = pd.read_csv('diabetes.csv')
# split data into X and y
X = dataset.values[:,0:8]
y = dataset.values[:,8]
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=7)
# fit model on all training data
model = XGBClassifier()
model.fit(X_train, y_train)
# model
print ('model', model)
print('Is xgboost.core.Booster object ',model.get_booster())
importance = model.get_booster().get_score()
print ('feature importance',importance)
importance_debug = get_score_debug(model.get_booster())
print ('feature importance_debug',importance_debug)

# make predictions for test data and evaluate
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Fit model using each importance as a threshold
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
	# select features using threshold
	selection = SelectFromModel(model, threshold=thresh, prefit=True)
	select_X_train = selection.transform(X_train)
	# train model
	selection_model = XGBClassifier()
	selection_model.fit(select_X_train, y_train)
	# eval model
	select_X_test = selection.transform(X_test)
	y_pred = selection_model.predict(select_X_test)
	predictions = [round(value) for value in y_pred]
	accuracy = accuracy_score(y_test, predictions)
	print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
# Out:
# model XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# Is xgboost.core.Booster object  <xgboost.core.Booster object at 0x11c655a20>
# feature importance {'f1': 110, 'f7': 123, 'f5': 95, 'f4': 43, 'f6': 76, 'f3': 50, 'f0': 42, 'f2': 53}
# what is fucking problem
# trees <class 'list'> 100 ['0:[f1<127.5] yes=1,no=2,missing=1\n\t1:[f7<28.5] yes=3,no=4,missing=3\n\t\t3:[f5<30.95] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.185586\n\t\t\t8:leaf=-0.128889\n\t\t4:[f5<26.35] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.173333\n\t\t\t10:leaf=-0.0324786\n\t2:[f5<28.15] yes=5,no=6,missing=5\n\t\t5:[f1<145.5] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.147826\n\t\t\t12:leaf=-0.0117647\n\t\t6:[f1<165.5] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.0458716\n\t\t\t14:leaf=0.15102\n', '0:[f1<127.5] yes=1,no=2,missing=1\n\t1:[f7<28.5] yes=3,no=4,missing=3\n\t\t3:[f5<30.95] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.169143\n\t\t\t8:leaf=-0.117053\n\t\t4:[f4<148] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.0804306\n\t\t\t10:leaf=0.0706011\n\t2:[f5<28.15] yes=5,no=6,missing=5\n\t\t5:[f1<145.5] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.136249\n\t\t\t12:leaf=-0.0108654\n\t\t6:[f6<0.434] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.029299\n\t\t\t14:leaf=0.124071\n', '0:[f1<130.5] yes=1,no=2,missing=1\n\t1:[f7<28.5] yes=3,no=4,missing=3\n\t\t3:[f3<39.5] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.14213\n\t\t\t8:leaf=-0.0516405\n\t\t4:[f5<26.35] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.155118\n\t\t\t10:leaf=-0.0180271\n\t2:[f5<29.9] yes=5,no=6,missing=5\n\t\t5:[f1<145.5] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.0961953\n\t\t\t12:leaf=-0.00184008\n\t\t6:[f1<165.5] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.0478779\n\t\t\t14:leaf=0.129708\n', '0:[f1<114.5] yes=1,no=2,missing=1\n\t1:[f6<0.6605] yes=3,no=4,missing=3\n\t\t3:[f0<11.5] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.129907\n\t\t\t8:leaf=-0.011259\n\t\t4:[f0<2.5] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.10864\n\t\t\t10:leaf=0.032116\n\t2:[f5<28.15] yes=5,no=6,missing=5\n\t\t5:[f1<145.5] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.113234\n\t\t\t12:leaf=-0.00989469\n\t\t6:[f1<165.5] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.0152025\n\t\t\t14:leaf=0.122661\n', '0:[f1<127.5] yes=1,no=2,missing=1\n\t1:[f7<28.5] yes=3,no=4,missing=3\n\t\t3:[f5<30.95] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.140264\n\t\t\t8:leaf=-0.0904884\n\t\t4:[f4<148] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.0626843\n\t\t\t10:leaf=0.069977\n\t2:[f5<28.15] yes=5,no=6,missing=5\n\t\t5:[f1<145.5] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.112856\n\t\t\t12:leaf=-0.00913913\n\t\t6:[f6<0.434] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.0178135\n\t\t\t14:leaf=0.105366\n', '0:[f1<114.5] yes=1,no=2,missing=1\n\t1:[f7<35.5] yes=3,no=4,missing=3\n\t\t3:[f0<6.5] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.118698\n\t\t\t8:leaf=-0.00470952\n\t\t4:[f4<141] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.0708182\n\t\t\t10:leaf=0.0738902\n\t2:[f5<27.55] yes=5,no=6,missing=5\n\t\t5:[f1<145.5] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.105386\n\t\t\t12:leaf=-0.00844151\n\t\t6:[f1<165.5] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.0121681\n\t\t\t14:leaf=0.11032\n', '0:[f1<114.5] yes=1,no=2,missing=1\n\t1:[f6<0.6605] yes=3,no=4,missing=3\n\t\t3:[f7<35.5] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.116819\n\t\t\t8:leaf=-0.0608473\n\t\t4:[f0<2.5] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.0884536\n\t\t\t10:leaf=0.0378507\n\t2:[f7<27.5] yes=5,no=6,missing=5\n\t\t5:[f5<35.6] yes=11,no=12,missing=11\n\t\t\t11:leaf=-0.0850963\n\t\t\t12:leaf=0.0127899\n\t\t6:[f7<56] yes=13,no=14,missing=13\n\t\t\t13:leaf=0.0572204\n\t\t\t14:leaf=-0.0647493\n', '0:[f1<130.5] yes=1,no=2,missing=1\n\t1:[f5<26.45] yes=3,no=4,missing=3\n\t\t3:leaf=-0.130374\n\t\t4:[f7<28.5] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.0858514\n\t\t\t8:leaf=-0.00344945\n\t2:[f5<29.9] yes=5,no=6,missing=5\n\t\t5:[f7<61] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.0147252\n\t\t\t10:leaf=-0.104622\n\t\t6:[f6<0.434] yes=11,no=12,missing=11\n\t\t\t11:leaf=0.0254277\n\t\t\t12:leaf=0.0957454\n', '0:[f1<101.5] yes=1,no=2,missing=1\n\t1:[f0<11.5] yes=3,no=4,missing=3\n\t\t3:[f6<1.181] yes=7,no=8,missing=7\n\t\t\t7:leaf=-0.113265\n\t\t\t8:leaf=0.0195017\n\t\t4:leaf=0.0302529\n\t2:[f5<26.45] yes=5,no=6,missing=5\n\t\t5:[f7<49.5] yes=9,no=10,missing=9\n\t\t\t9:leaf=-0.1 ...
# tree 0:[f1<127.5] yes=1,no=2,missing=1
# 	1:[f7<28.5] yes=3,no=4,missing=3
# 		3:[f5<30.95] yes=7,no=8,missing=7
# 			7:leaf=-0.185586
# 			8:leaf=-0.128889
# 		4:[f5<26.35] yes=9,no=10,missing=9
# 			9:leaf=-0.173333
# 			10:leaf=-0.0324786
# 	2:[f5<28.15] yes=5,no=6,missing=5
# 		5:[f1<145.5] yes=11,no=12,missing=11
# 			11:leaf=-0.147826
# 			12:leaf=-0.0117647
# 		6:[f1<165.5] yes=13,no=14,missing=13
# 			13:leaf=0.0458716
# 			14:leaf=0.15102
#
# line 0:[f1<127.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<127.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<28.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<28.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f5<30.95] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f5<30.95] yes=7,no=8,missing=7'] 2
# feature id f5
# line 			7:leaf=-0.185586
# arr ['\t\t\t7:leaf=-0.185586'] 1
# line 			8:leaf=-0.128889
# arr ['\t\t\t8:leaf=-0.128889'] 1
# line 		4:[f5<26.35] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f5<26.35] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=-0.173333
# arr ['\t\t\t9:leaf=-0.173333'] 1
# line 			10:leaf=-0.0324786
# arr ['\t\t\t10:leaf=-0.0324786'] 1
# line 	2:[f5<28.15] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<28.15] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f1<145.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<145.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.147826
# arr ['\t\t\t11:leaf=-0.147826'] 1
# line 			12:leaf=-0.0117647
# arr ['\t\t\t12:leaf=-0.0117647'] 1
# line 		6:[f1<165.5] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f1<165.5] yes=13,no=14,missing=13'] 2
# feature id f1
# line 			13:leaf=0.0458716
# arr ['\t\t\t13:leaf=0.0458716'] 1
# line 			14:leaf=0.15102
# arr ['\t\t\t14:leaf=0.15102'] 1
# line
# arr [''] 1
# tree 0:[f1<127.5] yes=1,no=2,missing=1
# 	1:[f7<28.5] yes=3,no=4,missing=3
# 		3:[f5<30.95] yes=7,no=8,missing=7
# 			7:leaf=-0.169143
# 			8:leaf=-0.117053
# 		4:[f4<148] yes=9,no=10,missing=9
# 			9:leaf=-0.0804306
# 			10:leaf=0.0706011
# 	2:[f5<28.15] yes=5,no=6,missing=5
# 		5:[f1<145.5] yes=11,no=12,missing=11
# 			11:leaf=-0.136249
# 			12:leaf=-0.0108654
# 		6:[f6<0.434] yes=13,no=14,missing=13
# 			13:leaf=0.029299
# 			14:leaf=0.124071
#
# line 0:[f1<127.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<127.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<28.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<28.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f5<30.95] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f5<30.95] yes=7,no=8,missing=7'] 2
# feature id f5
# line 			7:leaf=-0.169143
# arr ['\t\t\t7:leaf=-0.169143'] 1
# line 			8:leaf=-0.117053
# arr ['\t\t\t8:leaf=-0.117053'] 1
# line 		4:[f4<148] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f4<148] yes=9,no=10,missing=9'] 2
# feature id f4
# line 			9:leaf=-0.0804306
# arr ['\t\t\t9:leaf=-0.0804306'] 1
# line 			10:leaf=0.0706011
# arr ['\t\t\t10:leaf=0.0706011'] 1
# line 	2:[f5<28.15] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<28.15] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f1<145.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<145.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.136249
# arr ['\t\t\t11:leaf=-0.136249'] 1
# line 			12:leaf=-0.0108654
# arr ['\t\t\t12:leaf=-0.0108654'] 1
# line 		6:[f6<0.434] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f6<0.434] yes=13,no=14,missing=13'] 2
# feature id f6
# line 			13:leaf=0.029299
# arr ['\t\t\t13:leaf=0.029299'] 1
# line 			14:leaf=0.124071
# arr ['\t\t\t14:leaf=0.124071'] 1
# line
# arr [''] 1
# tree 0:[f1<130.5] yes=1,no=2,missing=1
# 	1:[f7<28.5] yes=3,no=4,missing=3
# 		3:[f3<39.5] yes=7,no=8,missing=7
# 			7:leaf=-0.14213
# 			8:leaf=-0.0516405
# 		4:[f5<26.35] yes=9,no=10,missing=9
# 			9:leaf=-0.155118
# 			10:leaf=-0.0180271
# 	2:[f5<29.9] yes=5,no=6,missing=5
# 		5:[f1<145.5] yes=11,no=12,missing=11
# 			11:leaf=-0.0961953
# 			12:leaf=-0.00184008
# 		6:[f1<165.5] yes=13,no=14,missing=13
# 			13:leaf=0.0478779
# 			14:leaf=0.129708
#
# line 0:[f1<130.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<130.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<28.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<28.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f3<39.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f3<39.5] yes=7,no=8,missing=7'] 2
# feature id f3
# line 			7:leaf=-0.14213
# arr ['\t\t\t7:leaf=-0.14213'] 1
# line 			8:leaf=-0.0516405
# arr ['\t\t\t8:leaf=-0.0516405'] 1
# line 		4:[f5<26.35] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f5<26.35] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=-0.155118
# arr ['\t\t\t9:leaf=-0.155118'] 1
# line 			10:leaf=-0.0180271
# arr ['\t\t\t10:leaf=-0.0180271'] 1
# line 	2:[f5<29.9] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<29.9] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f1<145.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<145.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.0961953
# arr ['\t\t\t11:leaf=-0.0961953'] 1
# line 			12:leaf=-0.00184008
# arr ['\t\t\t12:leaf=-0.00184008'] 1
# line 		6:[f1<165.5] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f1<165.5] yes=13,no=14,missing=13'] 2
# feature id f1
# line 			13:leaf=0.0478779
# arr ['\t\t\t13:leaf=0.0478779'] 1
# line 			14:leaf=0.129708
# arr ['\t\t\t14:leaf=0.129708'] 1
# line
# arr [''] 1
# tree 0:[f1<114.5] yes=1,no=2,missing=1
# 	1:[f6<0.6605] yes=3,no=4,missing=3
# 		3:[f0<11.5] yes=7,no=8,missing=7
# 			7:leaf=-0.129907
# 			8:leaf=-0.011259
# 		4:[f0<2.5] yes=9,no=10,missing=9
# 			9:leaf=-0.10864
# 			10:leaf=0.032116
# 	2:[f5<28.15] yes=5,no=6,missing=5
# 		5:[f1<145.5] yes=11,no=12,missing=11
# 			11:leaf=-0.113234
# 			12:leaf=-0.00989469
# 		6:[f1<165.5] yes=13,no=14,missing=13
# 			13:leaf=0.0152025
# 			14:leaf=0.122661
#
# line 0:[f1<114.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<114.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f6<0.6605] yes=3,no=4,missing=3
# arr ['\t1:', 'f6<0.6605] yes=3,no=4,missing=3'] 2
# feature id f6
# line 		3:[f0<11.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f0<11.5] yes=7,no=8,missing=7'] 2
# feature id f0
# line 			7:leaf=-0.129907
# arr ['\t\t\t7:leaf=-0.129907'] 1
# line 			8:leaf=-0.011259
# arr ['\t\t\t8:leaf=-0.011259'] 1
# line 		4:[f0<2.5] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f0<2.5] yes=9,no=10,missing=9'] 2
# feature id f0
# line 			9:leaf=-0.10864
# arr ['\t\t\t9:leaf=-0.10864'] 1
# line 			10:leaf=0.032116
# arr ['\t\t\t10:leaf=0.032116'] 1
# line 	2:[f5<28.15] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<28.15] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f1<145.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<145.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.113234
# arr ['\t\t\t11:leaf=-0.113234'] 1
# line 			12:leaf=-0.00989469
# arr ['\t\t\t12:leaf=-0.00989469'] 1
# line 		6:[f1<165.5] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f1<165.5] yes=13,no=14,missing=13'] 2
# feature id f1
# line 			13:leaf=0.0152025
# arr ['\t\t\t13:leaf=0.0152025'] 1
# line 			14:leaf=0.122661
# arr ['\t\t\t14:leaf=0.122661'] 1
# line
# arr [''] 1
# tree 0:[f1<127.5] yes=1,no=2,missing=1
# 	1:[f7<28.5] yes=3,no=4,missing=3
# 		3:[f5<30.95] yes=7,no=8,missing=7
# 			7:leaf=-0.140264
# 			8:leaf=-0.0904884
# 		4:[f4<148] yes=9,no=10,missing=9
# 			9:leaf=-0.0626843
# 			10:leaf=0.069977
# 	2:[f5<28.15] yes=5,no=6,missing=5
# 		5:[f1<145.5] yes=11,no=12,missing=11
# 			11:leaf=-0.112856
# 			12:leaf=-0.00913913
# 		6:[f6<0.434] yes=13,no=14,missing=13
# 			13:leaf=0.0178135
# 			14:leaf=0.105366
#
# line 0:[f1<127.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<127.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<28.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<28.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f5<30.95] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f5<30.95] yes=7,no=8,missing=7'] 2
# feature id f5
# line 			7:leaf=-0.140264
# arr ['\t\t\t7:leaf=-0.140264'] 1
# line 			8:leaf=-0.0904884
# arr ['\t\t\t8:leaf=-0.0904884'] 1
# line 		4:[f4<148] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f4<148] yes=9,no=10,missing=9'] 2
# feature id f4
# line 			9:leaf=-0.0626843
# arr ['\t\t\t9:leaf=-0.0626843'] 1
# line 			10:leaf=0.069977
# arr ['\t\t\t10:leaf=0.069977'] 1
# line 	2:[f5<28.15] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<28.15] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f1<145.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<145.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.112856
# arr ['\t\t\t11:leaf=-0.112856'] 1
# line 			12:leaf=-0.00913913
# arr ['\t\t\t12:leaf=-0.00913913'] 1
# line 		6:[f6<0.434] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f6<0.434] yes=13,no=14,missing=13'] 2
# feature id f6
# line 			13:leaf=0.0178135
# arr ['\t\t\t13:leaf=0.0178135'] 1
# line 			14:leaf=0.105366
# arr ['\t\t\t14:leaf=0.105366'] 1
# line
# arr [''] 1
# tree 0:[f1<114.5] yes=1,no=2,missing=1
# 	1:[f7<35.5] yes=3,no=4,missing=3
# 		3:[f0<6.5] yes=7,no=8,missing=7
# 			7:leaf=-0.118698
# 			8:leaf=-0.00470952
# 		4:[f4<141] yes=9,no=10,missing=9
# 			9:leaf=-0.0708182
# 			10:leaf=0.0738902
# 	2:[f5<27.55] yes=5,no=6,missing=5
# 		5:[f1<145.5] yes=11,no=12,missing=11
# 			11:leaf=-0.105386
# 			12:leaf=-0.00844151
# 		6:[f1<165.5] yes=13,no=14,missing=13
# 			13:leaf=0.0121681
# 			14:leaf=0.11032
#
# line 0:[f1<114.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<114.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<35.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<35.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f0<6.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f0<6.5] yes=7,no=8,missing=7'] 2
# feature id f0
# line 			7:leaf=-0.118698
# arr ['\t\t\t7:leaf=-0.118698'] 1
# line 			8:leaf=-0.00470952
# arr ['\t\t\t8:leaf=-0.00470952'] 1
# line 		4:[f4<141] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f4<141] yes=9,no=10,missing=9'] 2
# feature id f4
# line 			9:leaf=-0.0708182
# arr ['\t\t\t9:leaf=-0.0708182'] 1
# line 			10:leaf=0.0738902
# arr ['\t\t\t10:leaf=0.0738902'] 1
# line 	2:[f5<27.55] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<27.55] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f1<145.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<145.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.105386
# arr ['\t\t\t11:leaf=-0.105386'] 1
# line 			12:leaf=-0.00844151
# arr ['\t\t\t12:leaf=-0.00844151'] 1
# line 		6:[f1<165.5] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f1<165.5] yes=13,no=14,missing=13'] 2
# feature id f1
# line 			13:leaf=0.0121681
# arr ['\t\t\t13:leaf=0.0121681'] 1
# line 			14:leaf=0.11032
# arr ['\t\t\t14:leaf=0.11032'] 1
# line
# arr [''] 1
# tree 0:[f1<114.5] yes=1,no=2,missing=1
# 	1:[f6<0.6605] yes=3,no=4,missing=3
# 		3:[f7<35.5] yes=7,no=8,missing=7
# 			7:leaf=-0.116819
# 			8:leaf=-0.0608473
# 		4:[f0<2.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0884536
# 			10:leaf=0.0378507
# 	2:[f7<27.5] yes=5,no=6,missing=5
# 		5:[f5<35.6] yes=11,no=12,missing=11
# 			11:leaf=-0.0850963
# 			12:leaf=0.0127899
# 		6:[f7<56] yes=13,no=14,missing=13
# 			13:leaf=0.0572204
# 			14:leaf=-0.0647493
#
# line 0:[f1<114.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<114.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f6<0.6605] yes=3,no=4,missing=3
# arr ['\t1:', 'f6<0.6605] yes=3,no=4,missing=3'] 2
# feature id f6
# line 		3:[f7<35.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<35.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.116819
# arr ['\t\t\t7:leaf=-0.116819'] 1
# line 			8:leaf=-0.0608473
# arr ['\t\t\t8:leaf=-0.0608473'] 1
# line 		4:[f0<2.5] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f0<2.5] yes=9,no=10,missing=9'] 2
# feature id f0
# line 			9:leaf=-0.0884536
# arr ['\t\t\t9:leaf=-0.0884536'] 1
# line 			10:leaf=0.0378507
# arr ['\t\t\t10:leaf=0.0378507'] 1
# line 	2:[f7<27.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<27.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f5<35.6] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f5<35.6] yes=11,no=12,missing=11'] 2
# feature id f5
# line 			11:leaf=-0.0850963
# arr ['\t\t\t11:leaf=-0.0850963'] 1
# line 			12:leaf=0.0127899
# arr ['\t\t\t12:leaf=0.0127899'] 1
# line 		6:[f7<56] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f7<56] yes=13,no=14,missing=13'] 2
# feature id f7
# line 			13:leaf=0.0572204
# arr ['\t\t\t13:leaf=0.0572204'] 1
# line 			14:leaf=-0.0647493
# arr ['\t\t\t14:leaf=-0.0647493'] 1
# line
# arr [''] 1
# tree 0:[f1<130.5] yes=1,no=2,missing=1
# 	1:[f5<26.45] yes=3,no=4,missing=3
# 		3:leaf=-0.130374
# 		4:[f7<28.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0858514
# 			8:leaf=-0.00344945
# 	2:[f5<29.9] yes=5,no=6,missing=5
# 		5:[f7<61] yes=9,no=10,missing=9
# 			9:leaf=-0.0147252
# 			10:leaf=-0.104622
# 		6:[f6<0.434] yes=11,no=12,missing=11
# 			11:leaf=0.0254277
# 			12:leaf=0.0957454
#
# line 0:[f1<130.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<130.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f5<26.45] yes=3,no=4,missing=3
# arr ['\t1:', 'f5<26.45] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:leaf=-0.130374
# arr ['\t\t3:leaf=-0.130374'] 1
# line 		4:[f7<28.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f7<28.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.0858514
# arr ['\t\t\t7:leaf=-0.0858514'] 1
# line 			8:leaf=-0.00344945
# arr ['\t\t\t8:leaf=-0.00344945'] 1
# line 	2:[f5<29.9] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<29.9] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f7<61] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f7<61] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0147252
# arr ['\t\t\t9:leaf=-0.0147252'] 1
# line 			10:leaf=-0.104622
# arr ['\t\t\t10:leaf=-0.104622'] 1
# line 		6:[f6<0.434] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f6<0.434] yes=11,no=12,missing=11'] 2
# feature id f6
# line 			11:leaf=0.0254277
# arr ['\t\t\t11:leaf=0.0254277'] 1
# line 			12:leaf=0.0957454
# arr ['\t\t\t12:leaf=0.0957454'] 1
# line
# arr [''] 1
# tree 0:[f1<101.5] yes=1,no=2,missing=1
# 	1:[f0<11.5] yes=3,no=4,missing=3
# 		3:[f6<1.181] yes=7,no=8,missing=7
# 			7:leaf=-0.113265
# 			8:leaf=0.0195017
# 		4:leaf=0.0302529
# 	2:[f5<26.45] yes=5,no=6,missing=5
# 		5:[f7<49.5] yes=9,no=10,missing=9
# 			9:leaf=-0.115234
# 			10:leaf=0.0190025
# 		6:[f6<0.528] yes=11,no=12,missing=11
# 			11:leaf=-0.0131559
# 			12:leaf=0.0676579
#
# line 0:[f1<101.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<101.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f0<11.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f0<11.5] yes=3,no=4,missing=3'] 2
# feature id f0
# line 		3:[f6<1.181] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f6<1.181] yes=7,no=8,missing=7'] 2
# feature id f6
# line 			7:leaf=-0.113265
# arr ['\t\t\t7:leaf=-0.113265'] 1
# line 			8:leaf=0.0195017
# arr ['\t\t\t8:leaf=0.0195017'] 1
# line 		4:leaf=0.0302529
# arr ['\t\t4:leaf=0.0302529'] 1
# line 	2:[f5<26.45] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<26.45] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f7<49.5] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f7<49.5] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.115234
# arr ['\t\t\t9:leaf=-0.115234'] 1
# line 			10:leaf=0.0190025
# arr ['\t\t\t10:leaf=0.0190025'] 1
# line 		6:[f6<0.528] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f6<0.528] yes=11,no=12,missing=11'] 2
# feature id f6
# line 			11:leaf=-0.0131559
# arr ['\t\t\t11:leaf=-0.0131559'] 1
# line 			12:leaf=0.0676579
# arr ['\t\t\t12:leaf=0.0676579'] 1
# line
# arr [''] 1
# tree 0:[f1<144.5] yes=1,no=2,missing=1
# 	1:[f5<26.95] yes=3,no=4,missing=3
# 		3:leaf=-0.114575
# 		4:[f1<101.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0800194
# 			8:leaf=-0.0080188
# 	2:[f7<24.5] yes=5,no=6,missing=5
# 		5:[f6<0.441] yes=9,no=10,missing=9
# 			9:leaf=-0.107185
# 			10:leaf=0.0550833
# 		6:[f7<56] yes=11,no=12,missing=11
# 			11:leaf=0.0774891
# 			12:leaf=-0.0268274
#
# line 0:[f1<144.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<144.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f5<26.95] yes=3,no=4,missing=3
# arr ['\t1:', 'f5<26.95] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:leaf=-0.114575
# arr ['\t\t3:leaf=-0.114575'] 1
# line 		4:[f1<101.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f1<101.5] yes=7,no=8,missing=7'] 2
# feature id f1
# line 			7:leaf=-0.0800194
# arr ['\t\t\t7:leaf=-0.0800194'] 1
# line 			8:leaf=-0.0080188
# arr ['\t\t\t8:leaf=-0.0080188'] 1
# line 	2:[f7<24.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<24.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f6<0.441] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f6<0.441] yes=9,no=10,missing=9'] 2
# feature id f6
# line 			9:leaf=-0.107185
# arr ['\t\t\t9:leaf=-0.107185'] 1
# line 			10:leaf=0.0550833
# arr ['\t\t\t10:leaf=0.0550833'] 1
# line 		6:[f7<56] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f7<56] yes=11,no=12,missing=11'] 2
# feature id f7
# line 			11:leaf=0.0774891
# arr ['\t\t\t11:leaf=0.0774891'] 1
# line 			12:leaf=-0.0268274
# arr ['\t\t\t12:leaf=-0.0268274'] 1
# line
# arr [''] 1
# tree 0:[f1<101.5] yes=1,no=2,missing=1
# 	1:[f4<170] yes=3,no=4,missing=3
# 		3:[f6<1.181] yes=7,no=8,missing=7
# 			7:leaf=-0.104511
# 			8:leaf=0.0231853
# 		4:leaf=0.0230379
# 	2:[f7<27.5] yes=5,no=6,missing=5
# 		5:[f5<31.1] yes=9,no=10,missing=9
# 			9:leaf=-0.099338
# 			10:leaf=-0.0137417
# 		6:[f5<26.9] yes=11,no=12,missing=11
# 			11:leaf=-0.0506797
# 			12:leaf=0.0396453
#
# line 0:[f1<101.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<101.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f4<170] yes=3,no=4,missing=3
# arr ['\t1:', 'f4<170] yes=3,no=4,missing=3'] 2
# feature id f4
# line 		3:[f6<1.181] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f6<1.181] yes=7,no=8,missing=7'] 2
# feature id f6
# line 			7:leaf=-0.104511
# arr ['\t\t\t7:leaf=-0.104511'] 1
# line 			8:leaf=0.0231853
# arr ['\t\t\t8:leaf=0.0231853'] 1
# line 		4:leaf=0.0230379
# arr ['\t\t4:leaf=0.0230379'] 1
# line 	2:[f7<27.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<27.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f5<31.1] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f5<31.1] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=-0.099338
# arr ['\t\t\t9:leaf=-0.099338'] 1
# line 			10:leaf=-0.0137417
# arr ['\t\t\t10:leaf=-0.0137417'] 1
# line 		6:[f5<26.9] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f5<26.9] yes=11,no=12,missing=11'] 2
# feature id f5
# line 			11:leaf=-0.0506797
# arr ['\t\t\t11:leaf=-0.0506797'] 1
# line 			12:leaf=0.0396453
# arr ['\t\t\t12:leaf=0.0396453'] 1
# line
# arr [''] 1
# tree 0:[f1<144.5] yes=1,no=2,missing=1
# 	1:[f5<26.95] yes=3,no=4,missing=3
# 		3:[f7<59] yes=7,no=8,missing=7
# 			7:leaf=-0.109957
# 			8:leaf=-0.034856
# 		4:[f6<0.8925] yes=9,no=10,missing=9
# 			9:leaf=-0.0374867
# 			10:leaf=0.0643838
# 	2:[f0<6.5] yes=5,no=6,missing=5
# 		5:[f1<165.5] yes=11,no=12,missing=11
# 			11:leaf=-0.0362081
# 			12:leaf=0.0727523
# 		6:[f7<54.5] yes=13,no=14,missing=13
# 			13:leaf=0.120228
# 			14:leaf=-0.0264443
#
# line 0:[f1<144.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<144.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f5<26.95] yes=3,no=4,missing=3
# arr ['\t1:', 'f5<26.95] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:[f7<59] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<59] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.109957
# arr ['\t\t\t7:leaf=-0.109957'] 1
# line 			8:leaf=-0.034856
# arr ['\t\t\t8:leaf=-0.034856'] 1
# line 		4:[f6<0.8925] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f6<0.8925] yes=9,no=10,missing=9'] 2
# feature id f6
# line 			9:leaf=-0.0374867
# arr ['\t\t\t9:leaf=-0.0374867'] 1
# line 			10:leaf=0.0643838
# arr ['\t\t\t10:leaf=0.0643838'] 1
# line 	2:[f0<6.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f0<6.5] yes=5,no=6,missing=5'] 2
# feature id f0
# line 		5:[f1<165.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f1<165.5] yes=11,no=12,missing=11'] 2
# feature id f1
# line 			11:leaf=-0.0362081
# arr ['\t\t\t11:leaf=-0.0362081'] 1
# line 			12:leaf=0.0727523
# arr ['\t\t\t12:leaf=0.0727523'] 1
# line 		6:[f7<54.5] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f7<54.5] yes=13,no=14,missing=13'] 2
# feature id f7
# line 			13:leaf=0.120228
# arr ['\t\t\t13:leaf=0.120228'] 1
# line 			14:leaf=-0.0264443
# arr ['\t\t\t14:leaf=-0.0264443'] 1
# line
# arr [''] 1
# tree 0:[f1<101.5] yes=1,no=2,missing=1
# 	1:[f4<170] yes=3,no=4,missing=3
# 		3:[f1<50] yes=7,no=8,missing=7
# 			7:leaf=0.0249394
# 			8:leaf=-0.0974655
# 		4:leaf=0.0235978
# 	2:[f7<27.5] yes=5,no=6,missing=5
# 		5:[f5<31.1] yes=9,no=10,missing=9
# 			9:leaf=-0.0913005
# 			10:leaf=-0.0109448
# 		6:[f7<56.5] yes=11,no=12,missing=11
# 			11:leaf=0.0350472
# 			12:leaf=-0.0513297
#
# line 0:[f1<101.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<101.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f4<170] yes=3,no=4,missing=3
# arr ['\t1:', 'f4<170] yes=3,no=4,missing=3'] 2
# feature id f4
# line 		3:[f1<50] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f1<50] yes=7,no=8,missing=7'] 2
# feature id f1
# line 			7:leaf=0.0249394
# arr ['\t\t\t7:leaf=0.0249394'] 1
# line 			8:leaf=-0.0974655
# arr ['\t\t\t8:leaf=-0.0974655'] 1
# line 		4:leaf=0.0235978
# arr ['\t\t4:leaf=0.0235978'] 1
# line 	2:[f7<27.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<27.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f5<31.1] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f5<31.1] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=-0.0913005
# arr ['\t\t\t9:leaf=-0.0913005'] 1
# line 			10:leaf=-0.0109448
# arr ['\t\t\t10:leaf=-0.0109448'] 1
# line 		6:[f7<56.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f7<56.5] yes=11,no=12,missing=11'] 2
# feature id f7
# line 			11:leaf=0.0350472
# arr ['\t\t\t11:leaf=0.0350472'] 1
# line 			12:leaf=-0.0513297
# arr ['\t\t\t12:leaf=-0.0513297'] 1
# line
# arr [''] 1
# tree 0:[f1<154.5] yes=1,no=2,missing=1
# 	1:[f5<26.95] yes=3,no=4,missing=3
# 		3:[f7<59] yes=7,no=8,missing=7
# 			7:leaf=-0.105843
# 			8:leaf=-0.0304776
# 		4:[f7<28.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0586025
# 			10:leaf=0.0120513
# 	2:[f7<58.5] yes=5,no=6,missing=5
# 		5:[f4<350] yes=11,no=12,missing=11
# 			11:leaf=0.0833717
# 			12:leaf=-0.0113007
# 		6:leaf=-0.0742559
#
# line 0:[f1<154.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<154.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f5<26.95] yes=3,no=4,missing=3
# arr ['\t1:', 'f5<26.95] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:[f7<59] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<59] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.105843
# arr ['\t\t\t7:leaf=-0.105843'] 1
# line 			8:leaf=-0.0304776
# arr ['\t\t\t8:leaf=-0.0304776'] 1
# line 		4:[f7<28.5] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f7<28.5] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0586025
# arr ['\t\t\t9:leaf=-0.0586025'] 1
# line 			10:leaf=0.0120513
# arr ['\t\t\t10:leaf=0.0120513'] 1
# line 	2:[f7<58.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<58.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f4<350] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f4<350] yes=11,no=12,missing=11'] 2
# feature id f4
# line 			11:leaf=0.0833717
# arr ['\t\t\t11:leaf=0.0833717'] 1
# line 			12:leaf=-0.0113007
# arr ['\t\t\t12:leaf=-0.0113007'] 1
# line 		6:leaf=-0.0742559
# arr ['\t\t6:leaf=-0.0742559'] 1
# line
# arr [''] 1
# tree 0:[f1<101.5] yes=1,no=2,missing=1
# 	1:[f0<11.5] yes=3,no=4,missing=3
# 		3:[f1<50] yes=7,no=8,missing=7
# 			7:leaf=0.0260448
# 			8:leaf=-0.0895006
# 		4:leaf=0.039431
# 	2:[f6<0.5085] yes=5,no=6,missing=5
# 		5:[f1<166.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0358946
# 			10:leaf=0.0691984
# 		6:[f5<27.7] yes=11,no=12,missing=11
# 			11:leaf=-0.0577319
# 			12:leaf=0.0612705
#
# line 0:[f1<101.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<101.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f0<11.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f0<11.5] yes=3,no=4,missing=3'] 2
# feature id f0
# line 		3:[f1<50] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f1<50] yes=7,no=8,missing=7'] 2
# feature id f1
# line 			7:leaf=0.0260448
# arr ['\t\t\t7:leaf=0.0260448'] 1
# line 			8:leaf=-0.0895006
# arr ['\t\t\t8:leaf=-0.0895006'] 1
# line 		4:leaf=0.039431
# arr ['\t\t4:leaf=0.039431'] 1
# line 	2:[f6<0.5085] yes=5,no=6,missing=5
# arr ['\t2:', 'f6<0.5085] yes=5,no=6,missing=5'] 2
# feature id f6
# line 		5:[f1<166.5] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f1<166.5] yes=9,no=10,missing=9'] 2
# feature id f1
# line 			9:leaf=-0.0358946
# arr ['\t\t\t9:leaf=-0.0358946'] 1
# line 			10:leaf=0.0691984
# arr ['\t\t\t10:leaf=0.0691984'] 1
# line 		6:[f5<27.7] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f5<27.7] yes=11,no=12,missing=11'] 2
# feature id f5
# line 			11:leaf=-0.0577319
# arr ['\t\t\t11:leaf=-0.0577319'] 1
# line 			12:leaf=0.0612705
# arr ['\t\t\t12:leaf=0.0612705'] 1
# line
# arr [''] 1
# tree 0:[f1<101.5] yes=1,no=2,missing=1
# 	1:[f7<25.5] yes=3,no=4,missing=3
# 		3:leaf=-0.109632
# 		4:[f3<21.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0760654
# 			8:leaf=-0.00462231
# 	2:[f7<24.5] yes=5,no=6,missing=5
# 		5:[f4<73] yes=9,no=10,missing=9
# 			9:leaf=-0.00214481
# 			10:leaf=-0.0891078
# 		6:[f6<0.71] yes=11,no=12,missing=11
# 			11:leaf=0.00151188
# 			12:leaf=0.0797677
#
# line 0:[f1<101.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<101.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<25.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<25.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:leaf=-0.109632
# arr ['\t\t3:leaf=-0.109632'] 1
# line 		4:[f3<21.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f3<21.5] yes=7,no=8,missing=7'] 2
# feature id f3
# line 			7:leaf=-0.0760654
# arr ['\t\t\t7:leaf=-0.0760654'] 1
# line 			8:leaf=-0.00462231
# arr ['\t\t\t8:leaf=-0.00462231'] 1
# line 	2:[f7<24.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<24.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f4<73] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f4<73] yes=9,no=10,missing=9'] 2
# feature id f4
# line 			9:leaf=-0.00214481
# arr ['\t\t\t9:leaf=-0.00214481'] 1
# line 			10:leaf=-0.0891078
# arr ['\t\t\t10:leaf=-0.0891078'] 1
# line 		6:[f6<0.71] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f6<0.71] yes=11,no=12,missing=11'] 2
# feature id f6
# line 			11:leaf=0.00151188
# arr ['\t\t\t11:leaf=0.00151188'] 1
# line 			12:leaf=0.0797677
# arr ['\t\t\t12:leaf=0.0797677'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f7<49.5] yes=3,no=4,missing=3
# 		3:leaf=-0.101782
# 		4:[f0<7.5] yes=7,no=8,missing=7
# 			7:leaf=0.0630526
# 			8:leaf=-0.0427181
# 	2:[f1<107.5] yes=5,no=6,missing=5
# 		5:[f7<25.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0898919
# 			10:leaf=-0.0189001
# 		6:[f6<0.8865] yes=11,no=12,missing=11
# 			11:leaf=0.00502194
# 			12:leaf=0.0946758
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f7<49.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<49.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:leaf=-0.101782
# arr ['\t\t3:leaf=-0.101782'] 1
# line 		4:[f0<7.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f0<7.5] yes=7,no=8,missing=7'] 2
# feature id f0
# line 			7:leaf=0.0630526
# arr ['\t\t\t7:leaf=0.0630526'] 1
# line 			8:leaf=-0.0427181
# arr ['\t\t\t8:leaf=-0.0427181'] 1
# line 	2:[f1<107.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f1<107.5] yes=5,no=6,missing=5'] 2
# feature id f1
# line 		5:[f7<25.5] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f7<25.5] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0898919
# arr ['\t\t\t9:leaf=-0.0898919'] 1
# line 			10:leaf=-0.0189001
# arr ['\t\t\t10:leaf=-0.0189001'] 1
# line 		6:[f6<0.8865] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f6<0.8865] yes=11,no=12,missing=11'] 2
# feature id f6
# line 			11:leaf=0.00502194
# arr ['\t\t\t11:leaf=0.00502194'] 1
# line 			12:leaf=0.0946758
# arr ['\t\t\t12:leaf=0.0946758'] 1
# line
# arr [''] 1
# tree 0:[f1<159.5] yes=1,no=2,missing=1
# 	1:[f5<26.45] yes=3,no=4,missing=3
# 		3:[f7<50.5] yes=7,no=8,missing=7
# 			7:leaf=-0.101933
# 			8:leaf=-0.00916484
# 		4:[f7<24.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0637494
# 			10:leaf=0.00224213
# 	2:[f7<56] yes=5,no=6,missing=5
# 		5:[f2<69] yes=11,no=12,missing=11
# 			11:leaf=0.0141563
# 			12:leaf=0.0831376
# 		6:leaf=-0.0378628
#
# line 0:[f1<159.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<159.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f5<26.45] yes=3,no=4,missing=3
# arr ['\t1:', 'f5<26.45] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:[f7<50.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<50.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.101933
# arr ['\t\t\t7:leaf=-0.101933'] 1
# line 			8:leaf=-0.00916484
# arr ['\t\t\t8:leaf=-0.00916484'] 1
# line 		4:[f7<24.5] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f7<24.5] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0637494
# arr ['\t\t\t9:leaf=-0.0637494'] 1
# line 			10:leaf=0.00224213
# arr ['\t\t\t10:leaf=0.00224213'] 1
# line 	2:[f7<56] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<56] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f2<69] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f2<69] yes=11,no=12,missing=11'] 2
# feature id f2
# line 			11:leaf=0.0141563
# arr ['\t\t\t11:leaf=0.0141563'] 1
# line 			12:leaf=0.0831376
# arr ['\t\t\t12:leaf=0.0831376'] 1
# line 		6:leaf=-0.0378628
# arr ['\t\t6:leaf=-0.0378628'] 1
# line
# arr [''] 1
# tree 0:[f1<99.5] yes=1,no=2,missing=1
# 	1:[f3<30.5] yes=3,no=4,missing=3
# 		3:[f7<42.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0978099
# 			8:leaf=-0.00380508
# 		4:[f1<90.5] yes=9,no=10,missing=9
# 			9:leaf=0.0322345
# 			10:leaf=-0.0853749
# 	2:[f7<28.5] yes=5,no=6,missing=5
# 		5:[f3<4] yes=11,no=12,missing=11
# 			11:leaf=0.0391772
# 			12:leaf=-0.050881
# 		6:[f6<0.2095] yes=13,no=14,missing=13
# 			13:leaf=-0.030885
# 			14:leaf=0.036767
#
# line 0:[f1<99.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<99.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f3<30.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f3<30.5] yes=3,no=4,missing=3'] 2
# feature id f3
# line 		3:[f7<42.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<42.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.0978099
# arr ['\t\t\t7:leaf=-0.0978099'] 1
# line 			8:leaf=-0.00380508
# arr ['\t\t\t8:leaf=-0.00380508'] 1
# line 		4:[f1<90.5] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f1<90.5] yes=9,no=10,missing=9'] 2
# feature id f1
# line 			9:leaf=0.0322345
# arr ['\t\t\t9:leaf=0.0322345'] 1
# line 			10:leaf=-0.0853749
# arr ['\t\t\t10:leaf=-0.0853749'] 1
# line 	2:[f7<28.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<28.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f3<4] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f3<4] yes=11,no=12,missing=11'] 2
# feature id f3
# line 			11:leaf=0.0391772
# arr ['\t\t\t11:leaf=0.0391772'] 1
# line 			12:leaf=-0.050881
# arr ['\t\t\t12:leaf=-0.050881'] 1
# line 		6:[f6<0.2095] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f6<0.2095] yes=13,no=14,missing=13'] 2
# feature id f6
# line 			13:leaf=-0.030885
# arr ['\t\t\t13:leaf=-0.030885'] 1
# line 			14:leaf=0.036767
# arr ['\t\t\t14:leaf=0.036767'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f7<49.5] yes=3,no=4,missing=3
# 		3:leaf=-0.0950622
# 		4:[f6<0.343] yes=7,no=8,missing=7
# 			7:leaf=0.0595204
# 			8:leaf=-0.0432706
# 	2:[f1<166.5] yes=5,no=6,missing=5
# 		5:[f6<0.71] yes=9,no=10,missing=9
# 			9:leaf=-0.0221567
# 			10:leaf=0.047422
# 		6:[f2<89] yes=11,no=12,missing=11
# 			11:leaf=0.0889612
# 			12:leaf=-0.00426104
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f7<49.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<49.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:leaf=-0.0950622
# arr ['\t\t3:leaf=-0.0950622'] 1
# line 		4:[f6<0.343] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f6<0.343] yes=7,no=8,missing=7'] 2
# feature id f6
# line 			7:leaf=0.0595204
# arr ['\t\t\t7:leaf=0.0595204'] 1
# line 			8:leaf=-0.0432706
# arr ['\t\t\t8:leaf=-0.0432706'] 1
# line 	2:[f1<166.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f1<166.5] yes=5,no=6,missing=5'] 2
# feature id f1
# line 		5:[f6<0.71] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f6<0.71] yes=9,no=10,missing=9'] 2
# feature id f6
# line 			9:leaf=-0.0221567
# arr ['\t\t\t9:leaf=-0.0221567'] 1
# line 			10:leaf=0.047422
# arr ['\t\t\t10:leaf=0.047422'] 1
# line 		6:[f2<89] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f2<89] yes=11,no=12,missing=11'] 2
# feature id f2
# line 			11:leaf=0.0889612
# arr ['\t\t\t11:leaf=0.0889612'] 1
# line 			12:leaf=-0.00426104
# arr ['\t\t\t12:leaf=-0.00426104'] 1
# line
# arr [''] 1
# tree 0:[f1<99.5] yes=1,no=2,missing=1
# 	1:[f7<25.5] yes=3,no=4,missing=3
# 		3:leaf=-0.100279
# 		4:[f7<27.5] yes=7,no=8,missing=7
# 			7:leaf=0.0454355
# 			8:leaf=-0.0499079
# 	2:[f6<0.5085] yes=5,no=6,missing=5
# 		5:[f3<6] yes=9,no=10,missing=9
# 			9:leaf=0.0247894
# 			10:leaf=-0.0444589
# 		6:[f5<27.7] yes=11,no=12,missing=11
# 			11:leaf=-0.0518808
# 			12:leaf=0.0521449
#
# line 0:[f1<99.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<99.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<25.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<25.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:leaf=-0.100279
# arr ['\t\t3:leaf=-0.100279'] 1
# line 		4:[f7<27.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f7<27.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=0.0454355
# arr ['\t\t\t7:leaf=0.0454355'] 1
# line 			8:leaf=-0.0499079
# arr ['\t\t\t8:leaf=-0.0499079'] 1
# line 	2:[f6<0.5085] yes=5,no=6,missing=5
# arr ['\t2:', 'f6<0.5085] yes=5,no=6,missing=5'] 2
# feature id f6
# line 		5:[f3<6] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f3<6] yes=9,no=10,missing=9'] 2
# feature id f3
# line 			9:leaf=0.0247894
# arr ['\t\t\t9:leaf=0.0247894'] 1
# line 			10:leaf=-0.0444589
# arr ['\t\t\t10:leaf=-0.0444589'] 1
# line 		6:[f5<27.7] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f5<27.7] yes=11,no=12,missing=11'] 2
# feature id f5
# line 			11:leaf=-0.0518808
# arr ['\t\t\t11:leaf=-0.0518808'] 1
# line 			12:leaf=0.0521449
# arr ['\t\t\t12:leaf=0.0521449'] 1
# line
# arr [''] 1
# tree 0:[f1<129.5] yes=1,no=2,missing=1
# 	1:[f5<26.45] yes=3,no=4,missing=3
# 		3:leaf=-0.0929337
# 		4:[f7<25.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0609919
# 			8:leaf=0.00230662
# 	2:[f5<34.25] yes=5,no=6,missing=5
# 		5:[f3<31.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0275124
# 			10:leaf=0.056134
# 		6:[f3<40.5] yes=11,no=12,missing=11
# 			11:leaf=0.0762341
# 			12:leaf=-0.0135993
#
# line 0:[f1<129.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<129.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f5<26.45] yes=3,no=4,missing=3
# arr ['\t1:', 'f5<26.45] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:leaf=-0.0929337
# arr ['\t\t3:leaf=-0.0929337'] 1
# line 		4:[f7<25.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f7<25.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.0609919
# arr ['\t\t\t7:leaf=-0.0609919'] 1
# line 			8:leaf=0.00230662
# arr ['\t\t\t8:leaf=0.00230662'] 1
# line 	2:[f5<34.25] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<34.25] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f3<31.5] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f3<31.5] yes=9,no=10,missing=9'] 2
# feature id f3
# line 			9:leaf=-0.0275124
# arr ['\t\t\t9:leaf=-0.0275124'] 1
# line 			10:leaf=0.056134
# arr ['\t\t\t10:leaf=0.056134'] 1
# line 		6:[f3<40.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f3<40.5] yes=11,no=12,missing=11'] 2
# feature id f3
# line 			11:leaf=0.0762341
# arr ['\t\t\t11:leaf=0.0762341'] 1
# line 			12:leaf=-0.0135993
# arr ['\t\t\t12:leaf=-0.0135993'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f7<49.5] yes=3,no=4,missing=3
# 		3:[f6<0.6755] yes=7,no=8,missing=7
# 			7:leaf=-0.0944102
# 			8:leaf=-0.0350596
# 		4:[f2<73] yes=9,no=10,missing=9
# 			9:leaf=0.0554193
# 			10:leaf=-0.037155
# 	2:[f1<166.5] yes=5,no=6,missing=5
# 		5:[f4<8] yes=11,no=12,missing=11
# 			11:leaf=0.0148608
# 			12:leaf=-0.0320401
# 		6:[f2<89] yes=13,no=14,missing=13
# 			13:leaf=0.0832844
# 			14:leaf=-0.00594101
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f7<49.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<49.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f6<0.6755] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f6<0.6755] yes=7,no=8,missing=7'] 2
# feature id f6
# line 			7:leaf=-0.0944102
# arr ['\t\t\t7:leaf=-0.0944102'] 1
# line 			8:leaf=-0.0350596
# arr ['\t\t\t8:leaf=-0.0350596'] 1
# line 		4:[f2<73] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f2<73] yes=9,no=10,missing=9'] 2
# feature id f2
# line 			9:leaf=0.0554193
# arr ['\t\t\t9:leaf=0.0554193'] 1
# line 			10:leaf=-0.037155
# arr ['\t\t\t10:leaf=-0.037155'] 1
# line 	2:[f1<166.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f1<166.5] yes=5,no=6,missing=5'] 2
# feature id f1
# line 		5:[f4<8] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f4<8] yes=11,no=12,missing=11'] 2
# feature id f4
# line 			11:leaf=0.0148608
# arr ['\t\t\t11:leaf=0.0148608'] 1
# line 			12:leaf=-0.0320401
# arr ['\t\t\t12:leaf=-0.0320401'] 1
# line 		6:[f2<89] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f2<89] yes=13,no=14,missing=13'] 2
# feature id f2
# line 			13:leaf=0.0832844
# arr ['\t\t\t13:leaf=0.0832844'] 1
# line 			14:leaf=-0.00594101
# arr ['\t\t\t14:leaf=-0.00594101'] 1
# line
# arr [''] 1
# tree 0:[f1<99.5] yes=1,no=2,missing=1
# 	1:[f7<25.5] yes=3,no=4,missing=3
# 		3:leaf=-0.096101
# 		4:[f3<21.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0700366
# 			8:leaf=0.00548949
# 	2:[f6<0.4215] yes=5,no=6,missing=5
# 		5:[f3<12.5] yes=9,no=10,missing=9
# 			9:leaf=0.0204571
# 			10:leaf=-0.0485828
# 		6:[f0<6.5] yes=11,no=12,missing=11
# 			11:leaf=0.00943209
# 			12:leaf=0.0847744
#
# line 0:[f1<99.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<99.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<25.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<25.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:leaf=-0.096101
# arr ['\t\t3:leaf=-0.096101'] 1
# line 		4:[f3<21.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f3<21.5] yes=7,no=8,missing=7'] 2
# feature id f3
# line 			7:leaf=-0.0700366
# arr ['\t\t\t7:leaf=-0.0700366'] 1
# line 			8:leaf=0.00548949
# arr ['\t\t\t8:leaf=0.00548949'] 1
# line 	2:[f6<0.4215] yes=5,no=6,missing=5
# arr ['\t2:', 'f6<0.4215] yes=5,no=6,missing=5'] 2
# feature id f6
# line 		5:[f3<12.5] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f3<12.5] yes=9,no=10,missing=9'] 2
# feature id f3
# line 			9:leaf=0.0204571
# arr ['\t\t\t9:leaf=0.0204571'] 1
# line 			10:leaf=-0.0485828
# arr ['\t\t\t10:leaf=-0.0485828'] 1
# line 		6:[f0<6.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f0<6.5] yes=11,no=12,missing=11'] 2
# feature id f0
# line 			11:leaf=0.00943209
# arr ['\t\t\t11:leaf=0.00943209'] 1
# line 			12:leaf=0.0847744
# arr ['\t\t\t12:leaf=0.0847744'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f1<153] yes=3,no=4,missing=3
# 		3:[f7<56.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0895393
# 			8:leaf=-0.0218382
# 		4:leaf=0.01863
# 	2:[f1<166.5] yes=5,no=6,missing=5
# 		5:[f6<0.8865] yes=9,no=10,missing=9
# 			9:leaf=-0.0146711
# 			10:leaf=0.0641683
# 		6:[f3<25.5] yes=11,no=12,missing=11
# 			11:leaf=0.0077293
# 			12:leaf=0.0893957
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f1<153] yes=3,no=4,missing=3
# arr ['\t1:', 'f1<153] yes=3,no=4,missing=3'] 2
# feature id f1
# line 		3:[f7<56.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<56.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.0895393
# arr ['\t\t\t7:leaf=-0.0895393'] 1
# line 			8:leaf=-0.0218382
# arr ['\t\t\t8:leaf=-0.0218382'] 1
# line 		4:leaf=0.01863
# arr ['\t\t4:leaf=0.01863'] 1
# line 	2:[f1<166.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f1<166.5] yes=5,no=6,missing=5'] 2
# feature id f1
# line 		5:[f6<0.8865] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f6<0.8865] yes=9,no=10,missing=9'] 2
# feature id f6
# line 			9:leaf=-0.0146711
# arr ['\t\t\t9:leaf=-0.0146711'] 1
# line 			10:leaf=0.0641683
# arr ['\t\t\t10:leaf=0.0641683'] 1
# line 		6:[f3<25.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f3<25.5] yes=11,no=12,missing=11'] 2
# feature id f3
# line 			11:leaf=0.0077293
# arr ['\t\t\t11:leaf=0.0077293'] 1
# line 			12:leaf=0.0893957
# arr ['\t\t\t12:leaf=0.0893957'] 1
# line
# arr [''] 1
# tree 0:[f1<99.5] yes=1,no=2,missing=1
# 	1:[f7<25.5] yes=3,no=4,missing=3
# 		3:leaf=-0.0937238
# 		4:[f7<27.5] yes=7,no=8,missing=7
# 			7:leaf=0.0505321
# 			8:leaf=-0.0425345
# 	2:[f2<15] yes=5,no=6,missing=5
# 		5:[f5<34.1] yes=9,no=10,missing=9
# 			9:leaf=0.111982
# 			10:leaf=0.0338628
# 		6:[f7<28.5] yes=11,no=12,missing=11
# 			11:leaf=-0.031672
# 			12:leaf=0.0167337
#
# line 0:[f1<99.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<99.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f7<25.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<25.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:leaf=-0.0937238
# arr ['\t\t3:leaf=-0.0937238'] 1
# line 		4:[f7<27.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f7<27.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=0.0505321
# arr ['\t\t\t7:leaf=0.0505321'] 1
# line 			8:leaf=-0.0425345
# arr ['\t\t\t8:leaf=-0.0425345'] 1
# line 	2:[f2<15] yes=5,no=6,missing=5
# arr ['\t2:', 'f2<15] yes=5,no=6,missing=5'] 2
# feature id f2
# line 		5:[f5<34.1] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f5<34.1] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=0.111982
# arr ['\t\t\t9:leaf=0.111982'] 1
# line 			10:leaf=0.0338628
# arr ['\t\t\t10:leaf=0.0338628'] 1
# line 		6:[f7<28.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f7<28.5] yes=11,no=12,missing=11'] 2
# feature id f7
# line 			11:leaf=-0.031672
# arr ['\t\t\t11:leaf=-0.031672'] 1
# line 			12:leaf=0.0167337
# arr ['\t\t\t12:leaf=0.0167337'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f1<153] yes=3,no=4,missing=3
# 		3:[f7<56.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0867197
# 			8:leaf=-0.0210214
# 		4:leaf=0.0174342
# 	2:[f6<0.501] yes=5,no=6,missing=5
# 		5:[f3<12.5] yes=9,no=10,missing=9
# 			9:leaf=0.0223986
# 			10:leaf=-0.0359865
# 		6:[f3<27.5] yes=11,no=12,missing=11
# 			11:leaf=-0.00635864
# 			12:leaf=0.0546594
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f1<153] yes=3,no=4,missing=3
# arr ['\t1:', 'f1<153] yes=3,no=4,missing=3'] 2
# feature id f1
# line 		3:[f7<56.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<56.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=-0.0867197
# arr ['\t\t\t7:leaf=-0.0867197'] 1
# line 			8:leaf=-0.0210214
# arr ['\t\t\t8:leaf=-0.0210214'] 1
# line 		4:leaf=0.0174342
# arr ['\t\t4:leaf=0.0174342'] 1
# line 	2:[f6<0.501] yes=5,no=6,missing=5
# arr ['\t2:', 'f6<0.501] yes=5,no=6,missing=5'] 2
# feature id f6
# line 		5:[f3<12.5] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f3<12.5] yes=9,no=10,missing=9'] 2
# feature id f3
# line 			9:leaf=0.0223986
# arr ['\t\t\t9:leaf=0.0223986'] 1
# line 			10:leaf=-0.0359865
# arr ['\t\t\t10:leaf=-0.0359865'] 1
# line 		6:[f3<27.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f3<27.5] yes=11,no=12,missing=11'] 2
# feature id f3
# line 			11:leaf=-0.00635864
# arr ['\t\t\t11:leaf=-0.00635864'] 1
# line 			12:leaf=0.0546594
# arr ['\t\t\t12:leaf=0.0546594'] 1
# line
# arr [''] 1
# tree 0:[f1<129.5] yes=1,no=2,missing=1
# 	1:[f6<0.202] yes=3,no=4,missing=3
# 		3:[f3<6] yes=7,no=8,missing=7
# 			7:leaf=-0.0298094
# 			8:leaf=-0.109058
# 		4:[f7<25.5] yes=9,no=10,missing=9
# 			9:leaf=-0.0522458
# 			10:leaf=0.00918415
# 	2:[f5<34.25] yes=5,no=6,missing=5
# 		5:[f7<56] yes=11,no=12,missing=11
# 			11:leaf=0.0109912
# 			12:leaf=-0.0722308
# 		6:[f2<73] yes=13,no=14,missing=13
# 			13:leaf=0.0997094
# 			14:leaf=0.016174
#
# line 0:[f1<129.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<129.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f6<0.202] yes=3,no=4,missing=3
# arr ['\t1:', 'f6<0.202] yes=3,no=4,missing=3'] 2
# feature id f6
# line 		3:[f3<6] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f3<6] yes=7,no=8,missing=7'] 2
# feature id f3
# line 			7:leaf=-0.0298094
# arr ['\t\t\t7:leaf=-0.0298094'] 1
# line 			8:leaf=-0.109058
# arr ['\t\t\t8:leaf=-0.109058'] 1
# line 		4:[f7<25.5] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f7<25.5] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0522458
# arr ['\t\t\t9:leaf=-0.0522458'] 1
# line 			10:leaf=0.00918415
# arr ['\t\t\t10:leaf=0.00918415'] 1
# line 	2:[f5<34.25] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<34.25] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f7<56] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f7<56] yes=11,no=12,missing=11'] 2
# feature id f7
# line 			11:leaf=0.0109912
# arr ['\t\t\t11:leaf=0.0109912'] 1
# line 			12:leaf=-0.0722308
# arr ['\t\t\t12:leaf=-0.0722308'] 1
# line 		6:[f2<73] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f2<73] yes=13,no=14,missing=13'] 2
# feature id f2
# line 			13:leaf=0.0997094
# arr ['\t\t\t13:leaf=0.0997094'] 1
# line 			14:leaf=0.016174
# arr ['\t\t\t14:leaf=0.016174'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f7<49.5] yes=3,no=4,missing=3
# 		3:[f6<0.4395] yes=7,no=8,missing=7
# 			7:leaf=-0.0937913
# 			8:leaf=-0.0382777
# 		4:[f2<73] yes=9,no=10,missing=9
# 			9:leaf=0.0570083
# 			10:leaf=-0.0359591
# 	2:[f1<166.5] yes=5,no=6,missing=5
# 		5:[f6<0.8865] yes=11,no=12,missing=11
# 			11:leaf=-0.0117852
# 			12:leaf=0.0577071
# 		6:[f3<25.5] yes=13,no=14,missing=13
# 			13:leaf=0.00442207
# 			14:leaf=0.0849029
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f7<49.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<49.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f6<0.4395] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f6<0.4395] yes=7,no=8,missing=7'] 2
# feature id f6
# line 			7:leaf=-0.0937913
# arr ['\t\t\t7:leaf=-0.0937913'] 1
# line 			8:leaf=-0.0382777
# arr ['\t\t\t8:leaf=-0.0382777'] 1
# line 		4:[f2<73] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f2<73] yes=9,no=10,missing=9'] 2
# feature id f2
# line 			9:leaf=0.0570083
# arr ['\t\t\t9:leaf=0.0570083'] 1
# line 			10:leaf=-0.0359591
# arr ['\t\t\t10:leaf=-0.0359591'] 1
# line 	2:[f1<166.5] yes=5,no=6,missing=5
# ...
# arr ['\t\t6:', 'f4<132.5] yes=9,no=10,missing=9'] 2
# feature id f4
# line 			9:leaf=0.0886021
# arr ['\t\t\t9:leaf=0.0886021'] 1
# line 			10:leaf=-0.0227166
# arr ['\t\t\t10:leaf=-0.0227166'] 1
# line
# arr [''] 1
# tree 0:[f5<22.8] yes=1,no=2,missing=1
# 	1:leaf=-0.0564524
# 	2:[f6<1.397] yes=3,no=4,missing=3
# 		3:[f6<1.1075] yes=5,no=6,missing=5
# 			5:leaf=0.000605911
# 			6:leaf=0.0696636
# 		4:leaf=-0.0552515
#
# line 0:[f5<22.8] yes=1,no=2,missing=1
# arr ['0:', 'f5<22.8] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:leaf=-0.0564524
# arr ['\t1:leaf=-0.0564524'] 1
# line 	2:[f6<1.397] yes=3,no=4,missing=3
# arr ['\t2:', 'f6<1.397] yes=3,no=4,missing=3'] 2
# feature id f6
# line 		3:[f6<1.1075] yes=5,no=6,missing=5
# arr ['\t\t3:', 'f6<1.1075] yes=5,no=6,missing=5'] 2
# feature id f6
# line 			5:leaf=0.000605911
# arr ['\t\t\t5:leaf=0.000605911'] 1
# line 			6:leaf=0.0696636
# arr ['\t\t\t6:leaf=0.0696636'] 1
# line 		4:leaf=-0.0552515
# arr ['\t\t4:leaf=-0.0552515'] 1
# line
# arr [''] 1
# tree 0:[f7<24.5] yes=1,no=2,missing=1
# 	1:[f3<13.5] yes=3,no=4,missing=3
# 		3:[f1<122] yes=7,no=8,missing=7
# 			7:leaf=0.0740032
# 			8:leaf=-0.0249505
# 		4:[f5<33.45] yes=9,no=10,missing=9
# 			9:leaf=-0.0843349
# 			10:leaf=-0.01429
# 	2:[f4<159] yes=5,no=6,missing=5
# 		5:[f4<26] yes=11,no=12,missing=11
# 			11:leaf=0.0106799
# 			12:leaf=-0.026045
# 		6:[f6<0.646] yes=13,no=14,missing=13
# 			13:leaf=0.00811832
# 			14:leaf=0.07434
#
# line 0:[f7<24.5] yes=1,no=2,missing=1
# arr ['0:', 'f7<24.5] yes=1,no=2,missing=1'] 2
# feature id f7
# line 	1:[f3<13.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f3<13.5] yes=3,no=4,missing=3'] 2
# feature id f3
# line 		3:[f1<122] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f1<122] yes=7,no=8,missing=7'] 2
# feature id f1
# line 			7:leaf=0.0740032
# arr ['\t\t\t7:leaf=0.0740032'] 1
# line 			8:leaf=-0.0249505
# arr ['\t\t\t8:leaf=-0.0249505'] 1
# line 		4:[f5<33.45] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f5<33.45] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=-0.0843349
# arr ['\t\t\t9:leaf=-0.0843349'] 1
# line 			10:leaf=-0.01429
# arr ['\t\t\t10:leaf=-0.01429'] 1
# line 	2:[f4<159] yes=5,no=6,missing=5
# arr ['\t2:', 'f4<159] yes=5,no=6,missing=5'] 2
# feature id f4
# line 		5:[f4<26] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f4<26] yes=11,no=12,missing=11'] 2
# feature id f4
# line 			11:leaf=0.0106799
# arr ['\t\t\t11:leaf=0.0106799'] 1
# line 			12:leaf=-0.026045
# arr ['\t\t\t12:leaf=-0.026045'] 1
# line 		6:[f6<0.646] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f6<0.646] yes=13,no=14,missing=13'] 2
# feature id f6
# line 			13:leaf=0.00811832
# arr ['\t\t\t13:leaf=0.00811832'] 1
# line 			14:leaf=0.07434
# arr ['\t\t\t14:leaf=0.07434'] 1
# line
# arr [''] 1
# tree 0:[f2<97] yes=1,no=2,missing=1
# 	1:[f2<87] yes=3,no=4,missing=3
# 		3:[f4<48.5] yes=5,no=6,missing=5
# 			5:leaf=0.0142359
# 			6:leaf=-0.0102718
# 		4:[f5<43] yes=7,no=8,missing=7
# 			7:leaf=-0.0647345
# 			8:leaf=0.0173308
# 	2:leaf=0.0467793
#
# line 0:[f2<97] yes=1,no=2,missing=1
# arr ['0:', 'f2<97] yes=1,no=2,missing=1'] 2
# feature id f2
# line 	1:[f2<87] yes=3,no=4,missing=3
# arr ['\t1:', 'f2<87] yes=3,no=4,missing=3'] 2
# feature id f2
# line 		3:[f4<48.5] yes=5,no=6,missing=5
# arr ['\t\t3:', 'f4<48.5] yes=5,no=6,missing=5'] 2
# feature id f4
# line 			5:leaf=0.0142359
# arr ['\t\t\t5:leaf=0.0142359'] 1
# line 			6:leaf=-0.0102718
# arr ['\t\t\t6:leaf=-0.0102718'] 1
# line 		4:[f5<43] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f5<43] yes=7,no=8,missing=7'] 2
# feature id f5
# line 			7:leaf=-0.0647345
# arr ['\t\t\t7:leaf=-0.0647345'] 1
# line 			8:leaf=0.0173308
# arr ['\t\t\t8:leaf=0.0173308'] 1
# line 	2:leaf=0.0467793
# arr ['\t2:leaf=0.0467793'] 1
# line
# arr [''] 1
# tree 0:[f7<55.5] yes=1,no=2,missing=1
# 	1:[f7<51.5] yes=3,no=4,missing=3
# 		3:[f7<46.5] yes=7,no=8,missing=7
# 			7:leaf=0.00311623
# 			8:leaf=-0.0477662
# 		4:[f5<34] yes=9,no=10,missing=9
# 			9:leaf=0.0761363
# 			10:leaf=0.0144365
# 	2:[f0<4.5] yes=5,no=6,missing=5
# 		5:leaf=0.0130294
# 		6:leaf=-0.071179
#
# line 0:[f7<55.5] yes=1,no=2,missing=1
# arr ['0:', 'f7<55.5] yes=1,no=2,missing=1'] 2
# feature id f7
# line 	1:[f7<51.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<51.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f7<46.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<46.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=0.00311623
# arr ['\t\t\t7:leaf=0.00311623'] 1
# line 			8:leaf=-0.0477662
# arr ['\t\t\t8:leaf=-0.0477662'] 1
# line 		4:[f5<34] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f5<34] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=0.0761363
# arr ['\t\t\t9:leaf=0.0761363'] 1
# line 			10:leaf=0.0144365
# arr ['\t\t\t10:leaf=0.0144365'] 1
# line 	2:[f0<4.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f0<4.5] yes=5,no=6,missing=5'] 2
# feature id f0
# line 		5:leaf=0.0130294
# arr ['\t\t5:leaf=0.0130294'] 1
# line 		6:leaf=-0.071179
# arr ['\t\t6:leaf=-0.071179'] 1
# line
# arr [''] 1
# tree 0:[f1<165.5] yes=1,no=2,missing=1
# 	1:[f4<224] yes=3,no=4,missing=3
# 		3:[f6<0.2445] yes=7,no=8,missing=7
# 			7:leaf=-0.0196806
# 			8:leaf=0.00758976
# 		4:[f7<36] yes=9,no=10,missing=9
# 			9:leaf=-0.0621585
# 			10:leaf=0.0279264
# 	2:[f4<137] yes=5,no=6,missing=5
# 		5:[f5<34.25] yes=11,no=12,missing=11
# 			11:leaf=-0.0556882
# 			12:leaf=0.0379788
# 		6:leaf=0.0769163
#
# line 0:[f1<165.5] yes=1,no=2,missing=1
# arr ['0:', 'f1<165.5] yes=1,no=2,missing=1'] 2
# feature id f1
# line 	1:[f4<224] yes=3,no=4,missing=3
# arr ['\t1:', 'f4<224] yes=3,no=4,missing=3'] 2
# feature id f4
# line 		3:[f6<0.2445] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f6<0.2445] yes=7,no=8,missing=7'] 2
# feature id f6
# line 			7:leaf=-0.0196806
# arr ['\t\t\t7:leaf=-0.0196806'] 1
# line 			8:leaf=0.00758976
# arr ['\t\t\t8:leaf=0.00758976'] 1
# line 		4:[f7<36] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f7<36] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0621585
# arr ['\t\t\t9:leaf=-0.0621585'] 1
# line 			10:leaf=0.0279264
# arr ['\t\t\t10:leaf=0.0279264'] 1
# line 	2:[f4<137] yes=5,no=6,missing=5
# arr ['\t2:', 'f4<137] yes=5,no=6,missing=5'] 2
# feature id f4
# line 		5:[f5<34.25] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f5<34.25] yes=11,no=12,missing=11'] 2
# feature id f5
# line 			11:leaf=-0.0556882
# arr ['\t\t\t11:leaf=-0.0556882'] 1
# line 			12:leaf=0.0379788
# arr ['\t\t\t12:leaf=0.0379788'] 1
# line 		6:leaf=0.0769163
# arr ['\t\t6:leaf=0.0769163'] 1
# line
# arr [''] 1
# tree 0:[f0<0.5] yes=1,no=2,missing=1
# 	1:[f2<67] yes=3,no=4,missing=3
# 		3:[f3<25.5] yes=7,no=8,missing=7
# 			7:leaf=0.0120766
# 			8:leaf=0.0864969
# 		4:[f7<30] yes=9,no=10,missing=9
# 			9:leaf=-0.0349141
# 			10:leaf=0.044157
# 	2:[f7<41.5] yes=5,no=6,missing=5
# 		5:[f0<4.5] yes=11,no=12,missing=11
# 			11:leaf=-0.0256288
# 			12:leaf=0.0116689
# 		6:[f4<109] yes=13,no=14,missing=13
# 			13:leaf=-0.00994122
# 			14:leaf=0.0714392
#
# line 0:[f0<0.5] yes=1,no=2,missing=1
# arr ['0:', 'f0<0.5] yes=1,no=2,missing=1'] 2
# feature id f0
# line 	1:[f2<67] yes=3,no=4,missing=3
# arr ['\t1:', 'f2<67] yes=3,no=4,missing=3'] 2
# feature id f2
# line 		3:[f3<25.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f3<25.5] yes=7,no=8,missing=7'] 2
# feature id f3
# line 			7:leaf=0.0120766
# arr ['\t\t\t7:leaf=0.0120766'] 1
# line 			8:leaf=0.0864969
# arr ['\t\t\t8:leaf=0.0864969'] 1
# line 		4:[f7<30] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f7<30] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0349141
# arr ['\t\t\t9:leaf=-0.0349141'] 1
# line 			10:leaf=0.044157
# arr ['\t\t\t10:leaf=0.044157'] 1
# line 	2:[f7<41.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<41.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f0<4.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f0<4.5] yes=11,no=12,missing=11'] 2
# feature id f0
# line 			11:leaf=-0.0256288
# arr ['\t\t\t11:leaf=-0.0256288'] 1
# line 			12:leaf=0.0116689
# arr ['\t\t\t12:leaf=0.0116689'] 1
# line 		6:[f4<109] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f4<109] yes=13,no=14,missing=13'] 2
# feature id f4
# line 			13:leaf=-0.00994122
# arr ['\t\t\t13:leaf=-0.00994122'] 1
# line 			14:leaf=0.0714392
# arr ['\t\t\t14:leaf=0.0714392'] 1
# line
# arr [''] 1
# tree 0:[f5<22.8] yes=1,no=2,missing=1
# 	1:leaf=-0.0545314
# 	2:[f5<23.9] yes=3,no=4,missing=3
# 		3:leaf=0.0574301
# 		4:[f5<26.45] yes=5,no=6,missing=5
# 			5:leaf=-0.0542126
# 			6:leaf=0.00306951
#
# line 0:[f5<22.8] yes=1,no=2,missing=1
# arr ['0:', 'f5<22.8] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:leaf=-0.0545314
# arr ['\t1:leaf=-0.0545314'] 1
# line 	2:[f5<23.9] yes=3,no=4,missing=3
# arr ['\t2:', 'f5<23.9] yes=3,no=4,missing=3'] 2
# feature id f5
# line 		3:leaf=0.0574301
# arr ['\t\t3:leaf=0.0574301'] 1
# line 		4:[f5<26.45] yes=5,no=6,missing=5
# arr ['\t\t4:', 'f5<26.45] yes=5,no=6,missing=5'] 2
# feature id f5
# line 			5:leaf=-0.0542126
# arr ['\t\t\t5:leaf=-0.0542126'] 1
# line 			6:leaf=0.00306951
# arr ['\t\t\t6:leaf=0.00306951'] 1
# line
# arr [''] 1
# tree 0:[f6<1.397] yes=1,no=2,missing=1
# 	1:[f6<1.1075] yes=3,no=4,missing=3
# 		3:[f1<165.5] yes=5,no=6,missing=5
# 			5:leaf=-0.00459921
# 			6:leaf=0.036308
# 		4:leaf=0.0668298
# 	2:leaf=-0.0541778
#
# line 0:[f6<1.397] yes=1,no=2,missing=1
# arr ['0:', 'f6<1.397] yes=1,no=2,missing=1'] 2
# feature id f6
# line 	1:[f6<1.1075] yes=3,no=4,missing=3
# arr ['\t1:', 'f6<1.1075] yes=3,no=4,missing=3'] 2
# feature id f6
# line 		3:[f1<165.5] yes=5,no=6,missing=5
# arr ['\t\t3:', 'f1<165.5] yes=5,no=6,missing=5'] 2
# feature id f1
# line 			5:leaf=-0.00459921
# arr ['\t\t\t5:leaf=-0.00459921'] 1
# line 			6:leaf=0.036308
# arr ['\t\t\t6:leaf=0.036308'] 1
# line 		4:leaf=0.0668298
# arr ['\t\t4:leaf=0.0668298'] 1
# line 	2:leaf=-0.0541778
# arr ['\t2:leaf=-0.0541778'] 1
# line
# arr [''] 1
# tree 0:[f7<55.5] yes=1,no=2,missing=1
# 	1:[f7<51.5] yes=3,no=4,missing=3
# 		3:[f0<12.5] yes=7,no=8,missing=7
# 			7:leaf=-0.00250892
# 			8:leaf=0.0564524
# 		4:leaf=0.0572811
# 	2:[f0<4.5] yes=5,no=6,missing=5
# 		5:leaf=0.0115106
# 		6:leaf=-0.0687387
#
# line 0:[f7<55.5] yes=1,no=2,missing=1
# arr ['0:', 'f7<55.5] yes=1,no=2,missing=1'] 2
# feature id f7
# line 	1:[f7<51.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<51.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f0<12.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f0<12.5] yes=7,no=8,missing=7'] 2
# feature id f0
# line 			7:leaf=-0.00250892
# arr ['\t\t\t7:leaf=-0.00250892'] 1
# line 			8:leaf=0.0564524
# arr ['\t\t\t8:leaf=0.0564524'] 1
# line 		4:leaf=0.0572811
# arr ['\t\t4:leaf=0.0572811'] 1
# line 	2:[f0<4.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f0<4.5] yes=5,no=6,missing=5'] 2
# feature id f0
# line 		5:leaf=0.0115106
# arr ['\t\t5:leaf=0.0115106'] 1
# line 		6:leaf=-0.0687387
# arr ['\t\t6:leaf=-0.0687387'] 1
# line
# arr [''] 1
# tree 0:[f0<0.5] yes=1,no=2,missing=1
# 	1:[f2<67] yes=3,no=4,missing=3
# 		3:[f3<25.5] yes=7,no=8,missing=7
# 			7:leaf=0.012518
# 			8:leaf=0.0812771
# 		4:[f7<30] yes=9,no=10,missing=9
# 			9:leaf=-0.0323548
# 			10:leaf=0.041247
# 	2:[f5<33] yes=5,no=6,missing=5
# 		5:[f7<33.5] yes=11,no=12,missing=11
# 			11:leaf=0.0337352
# 			12:leaf=-0.0114652
# 		6:[f3<33.5] yes=13,no=14,missing=13
# 			13:leaf=-0.0295394
# 			14:leaf=0.0122029
#
# line 0:[f0<0.5] yes=1,no=2,missing=1
# arr ['0:', 'f0<0.5] yes=1,no=2,missing=1'] 2
# feature id f0
# line 	1:[f2<67] yes=3,no=4,missing=3
# arr ['\t1:', 'f2<67] yes=3,no=4,missing=3'] 2
# feature id f2
# line 		3:[f3<25.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f3<25.5] yes=7,no=8,missing=7'] 2
# feature id f3
# line 			7:leaf=0.012518
# arr ['\t\t\t7:leaf=0.012518'] 1
# line 			8:leaf=0.0812771
# arr ['\t\t\t8:leaf=0.0812771'] 1
# line 		4:[f7<30] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f7<30] yes=9,no=10,missing=9'] 2
# feature id f7
# line 			9:leaf=-0.0323548
# arr ['\t\t\t9:leaf=-0.0323548'] 1
# line 			10:leaf=0.041247
# arr ['\t\t\t10:leaf=0.041247'] 1
# line 	2:[f5<33] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<33] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f7<33.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f7<33.5] yes=11,no=12,missing=11'] 2
# feature id f7
# line 			11:leaf=0.0337352
# arr ['\t\t\t11:leaf=0.0337352'] 1
# line 			12:leaf=-0.0114652
# arr ['\t\t\t12:leaf=-0.0114652'] 1
# line 		6:[f3<33.5] yes=13,no=14,missing=13
# arr ['\t\t6:', 'f3<33.5] yes=13,no=14,missing=13'] 2
# feature id f3
# line 			13:leaf=-0.0295394
# arr ['\t\t\t13:leaf=-0.0295394'] 1
# line 			14:leaf=0.0122029
# arr ['\t\t\t14:leaf=0.0122029'] 1
# line
# arr [''] 1
# tree 0:[f7<24.5] yes=1,no=2,missing=1
# 	1:[f3<13.5] yes=3,no=4,missing=3
# 		3:[f7<23.5] yes=7,no=8,missing=7
# 			7:leaf=0.0594699
# 			8:leaf=-0.0394649
# 		4:[f5<33.45] yes=9,no=10,missing=9
# 			9:leaf=-0.0821344
# 			10:leaf=-0.0144264
# 	2:[f5<48.1] yes=5,no=6,missing=5
# 		5:[f2<84.5] yes=11,no=12,missing=11
# 			11:leaf=0.00904315
# 			12:leaf=-0.0337008
# 		6:leaf=0.07406
#
# line 0:[f7<24.5] yes=1,no=2,missing=1
# arr ['0:', 'f7<24.5] yes=1,no=2,missing=1'] 2
# feature id f7
# line 	1:[f3<13.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f3<13.5] yes=3,no=4,missing=3'] 2
# feature id f3
# line 		3:[f7<23.5] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f7<23.5] yes=7,no=8,missing=7'] 2
# feature id f7
# line 			7:leaf=0.0594699
# arr ['\t\t\t7:leaf=0.0594699'] 1
# line 			8:leaf=-0.0394649
# arr ['\t\t\t8:leaf=-0.0394649'] 1
# line 		4:[f5<33.45] yes=9,no=10,missing=9
# arr ['\t\t4:', 'f5<33.45] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=-0.0821344
# arr ['\t\t\t9:leaf=-0.0821344'] 1
# line 			10:leaf=-0.0144264
# arr ['\t\t\t10:leaf=-0.0144264'] 1
# line 	2:[f5<48.1] yes=5,no=6,missing=5
# arr ['\t2:', 'f5<48.1] yes=5,no=6,missing=5'] 2
# feature id f5
# line 		5:[f2<84.5] yes=11,no=12,missing=11
# arr ['\t\t5:', 'f2<84.5] yes=11,no=12,missing=11'] 2
# feature id f2
# line 			11:leaf=0.00904315
# arr ['\t\t\t11:leaf=0.00904315'] 1
# line 			12:leaf=-0.0337008
# arr ['\t\t\t12:leaf=-0.0337008'] 1
# line 		6:leaf=0.07406
# arr ['\t\t6:leaf=0.07406'] 1
# line
# arr [''] 1
# tree 0:[f5<26.45] yes=1,no=2,missing=1
# 	1:[f7<49.5] yes=3,no=4,missing=3
# 		3:[f4<47] yes=7,no=8,missing=7
# 			7:leaf=-0.0699601
# 			8:leaf=-0.0073675
# 		4:leaf=0.0167038
# 	2:[f7<57.5] yes=5,no=6,missing=5
# 		5:[f5<33.75] yes=9,no=10,missing=9
# 			9:leaf=0.0204759
# 			10:leaf=-0.005841
# 		6:[f0<4.5] yes=11,no=12,missing=11
# 			11:leaf=-0.00854026
# 			12:leaf=-0.0638713
#
# line 0:[f5<26.45] yes=1,no=2,missing=1
# arr ['0:', 'f5<26.45] yes=1,no=2,missing=1'] 2
# feature id f5
# line 	1:[f7<49.5] yes=3,no=4,missing=3
# arr ['\t1:', 'f7<49.5] yes=3,no=4,missing=3'] 2
# feature id f7
# line 		3:[f4<47] yes=7,no=8,missing=7
# arr ['\t\t3:', 'f4<47] yes=7,no=8,missing=7'] 2
# feature id f4
# line 			7:leaf=-0.0699601
# arr ['\t\t\t7:leaf=-0.0699601'] 1
# line 			8:leaf=-0.0073675
# arr ['\t\t\t8:leaf=-0.0073675'] 1
# line 		4:leaf=0.0167038
# arr ['\t\t4:leaf=0.0167038'] 1
# line 	2:[f7<57.5] yes=5,no=6,missing=5
# arr ['\t2:', 'f7<57.5] yes=5,no=6,missing=5'] 2
# feature id f7
# line 		5:[f5<33.75] yes=9,no=10,missing=9
# arr ['\t\t5:', 'f5<33.75] yes=9,no=10,missing=9'] 2
# feature id f5
# line 			9:leaf=0.0204759
# arr ['\t\t\t9:leaf=0.0204759'] 1
# line 			10:leaf=-0.005841
# arr ['\t\t\t10:leaf=-0.005841'] 1
# line 		6:[f0<4.5] yes=11,no=12,missing=11
# arr ['\t\t6:', 'f0<4.5] yes=11,no=12,missing=11'] 2
# feature id f0
# line 			11:leaf=-0.00854026
# arr ['\t\t\t11:leaf=-0.00854026'] 1
# line 			12:leaf=-0.0638713
# arr ['\t\t\t12:leaf=-0.0638713'] 1
# line
# arr [''] 1
# tree 0:[f2<97] yes=1,no=2,missing=1
# 	1:[f2<87] yes=3,no=4,missing=3
# 		3:[f4<48.5] yes=5,no=6,missing=5
# 			5:leaf=0.0137286
# 			6:leaf=-0.010561
# 		4:[f1<125.5] yes=7,no=8,missing=7
# 			7:leaf=-0.0822614
# 			8:leaf=-0.0096177
# 	2:leaf=0.0453768
#
# line 0:[f2<97] yes=1,no=2,missing=1
# arr ['0:', 'f2<97] yes=1,no=2,missing=1'] 2
# feature id f2
# line 	1:[f2<87] yes=3,no=4,missing=3
# arr ['\t1:', 'f2<87] yes=3,no=4,missing=3'] 2
# feature id f2
# line 		3:[f4<48.5] yes=5,no=6,missing=5
# arr ['\t\t3:', 'f4<48.5] yes=5,no=6,missing=5'] 2
# feature id f4
# line 			5:leaf=0.0137286
# arr ['\t\t\t5:leaf=0.0137286'] 1
# line 			6:leaf=-0.010561
# arr ['\t\t\t6:leaf=-0.010561'] 1
# line 		4:[f1<125.5] yes=7,no=8,missing=7
# arr ['\t\t4:', 'f1<125.5] yes=7,no=8,missing=7'] 2
# feature id f1
# line 			7:leaf=-0.0822614
# arr ['\t\t\t7:leaf=-0.0822614'] 1
# line 			8:leaf=-0.0096177
# arr ['\t\t\t8:leaf=-0.0096177'] 1
# line 	2:leaf=0.0453768
# arr ['\t2:leaf=0.0453768'] 1
# line
# arr [''] 1
# feature importance_debug {'f1': 110, 'f7': 123, 'f5': 95, 'f4': 43, 'f6': 76, 'f3': 50, 'f0': 42, 'f2': 53}
# Accuracy: 77.95%
# Thresh=0.071, n=8, Accuracy: 77.95%
# Thresh=0.073, n=7, Accuracy: 76.38%
# Thresh=0.084, n=6, Accuracy: 77.56%
# Thresh=0.090, n=5, Accuracy: 76.38%
# Thresh=0.128, n=4, Accuracy: 76.38%
# Thresh=0.160, n=3, Accuracy: 74.80%
# Thresh=0.186, n=2, Accuracy: 71.65%
# Thresh=0.208, n=1, Accuracy: 63.78%

# %%
model.feature_importances_
# Out:
# array([ 0.07094595,  0.1858108 ,  0.08952703,  0.08445946,  0.07263514,
#         0.16047297,  0.12837838,  0.20777027], dtype=float32)

# %%
from tqdm import tqdm
from glob import glob
def read_multiple_csv(path, col = None):

    # glob(path+'/*'): return a list, which consist of each files in path

    if col is None:
        df = pd.concat([pd.read_csv(f) for f in tqdm(sorted(glob(path+'/*')))])
    else:
        df = pd.concat([pd.read_csv(f)[col] for f in tqdm(sorted(glob(path+'/*')))])
    return df
def load_pred_feature(name, keep_all = False):
    
    if keep_all == False:
        #==============================================================================
        print('keep top imp')
        #==============================================================================
        col = keep_top_item()
        if name=='test':
            col.remove('is_churn') # feature中沒有is_churn
        df = read_multiple_csv('../feature/{}/all'.format(name), col)
        #df = read_multiple_csv('../feature/{}/all_sampling_for_developing'.format(name).format(name), col)
    else:
        #path = '../feature/{}/all_sampling_for_developing'.format(name)
        df = read_multiple_csv('../feature/{}/all'.format(name)) 
    
    print('{}.shape:{}\n'.format(name, df.shape))
    
    return df
def split_build_valid(valid_size = 0.05):
    # train/val split by user
    train_user['is_valid'] = np.random.choice([0,1], size=len(train_user), 
                                              p=[1-valid_size, valid_size]) # randomly pick someone as validation user
    # is_valid: 1 if the user is validating user else 0
    valid_n = train_user['is_valid'].sum()
    build_n = (train_user.shape[0] - valid_n)
    print('build user:{}, valid user:{}'.format(build_n, valid_n))
    valid_user = train_user[train_user['is_valid']==1].msno
    is_valid = X_train.msno.isin(valid_user)
    # to create the XGBoost matrices that will be used to train the model using XGBoost. 
    x_train = X_train[~is_valid].drop('msno', axis=1)
    y_train = Y_train[~is_valid]
    x_val = X_train[is_valid].drop('msno', axis=1)
    y_val = Y_train[is_valid]
    print('FINAL SHAPE')
    print('x_train.shape:{0}'.format(x_train.shape))
    print('x_val.shape:{0}'.format(x_val.shape))

    return x_train.values[:,7:10], y_train.values, x_val.values[:,7:10], y_val.values

# %%
#==============================================================================
# prepare
#==============================================================================
train = pd.concat([load_pred_feature('trainW-0', keep_all = True),
                   # utils.load_pred_feature('trainW-1'),
                   # utils.load_pred_feature('trainW-2'),
                   ], ignore_index=True).head(n = 3000)
# Out:
# 100%|██████████| 20/20 [01:49<00:00,  5.50s/it]
# trainW-0.shape:(881896, 653)

# %%
model = XGBClassifier(objective = 'binary:logistic',
                    max_depth = 100, learning_rate = 0.1, min_child_weight = 20)
model.fit(train[train.columns.tolist()[500:]], train['is_churn'], 
          eval_metric ='logloss' ,eval_set = [(train[train.columns.tolist()[500:]],train['is_churn'])],
          early_stopping_rounds = 10)
# Out:
# [0]	validation_0-logloss:0.598259
# Will train until validation_0-logloss hasn't improved in 10 rounds.
# [1]	validation_0-logloss:0.520528
# [2]	validation_0-logloss:0.455696
# [3]	validation_0-logloss:0.400887
# [4]	validation_0-logloss:0.354062
# [5]	validation_0-logloss:0.313721
# [6]	validation_0-logloss:0.27873
# [7]	validation_0-logloss:0.248208
# [8]	validation_0-logloss:0.22146
# [9]	validation_0-logloss:0.197925
# [10]	validation_0-logloss:0.177149
# [11]	validation_0-logloss:0.158754
# [12]	validation_0-logloss:0.142427
# [13]	validation_0-logloss:0.127904
# [14]	validation_0-logloss:0.114962
# [15]	validation_0-logloss:0.103408
# [16]	validation_0-logloss:0.093079
# [17]	validation_0-logloss:0.083834
# [18]	validation_0-logloss:0.075549
# [19]	validation_0-logloss:0.068117
# [20]	validation_0-logloss:0.061444
# [21]	validation_0-logloss:0.055448
# [22]	validation_0-logloss:0.050056
# [23]	validation_0-logloss:0.045205
# [24]	validation_0-logloss:0.040837
# [25]	validation_0-logloss:0.036904
# [26]	validation_0-logloss:0.033359
# [27]	validation_0-logloss:0.030163
# [28]	validation_0-logloss:0.02728
# [29]	validation_0-logloss:0.02468
# [30]	validation_0-logloss:0.022334
# [31]	validation_0-logloss:0.020216
# [32]	validation_0-logloss:0.018303
# [33]	validation_0-logloss:0.016576
# [34]	validation_0-logloss:0.015016
# [35]	validation_0-logloss:0.013607
# [36]	validation_0-logloss:0.012333
# [37]	validation_0-logloss:0.011183
# [38]	validation_0-logloss:0.010143
# [39]	validation_0-logloss:0.009202
# [40]	validation_0-logloss:0.008352
# [41]	validation_0-logloss:0.007584
# [42]	validation_0-logloss:0.006889
# [43]	validation_0-logloss:0.00626
# [44]	validation_0-logloss:0.00626
# [45]	validation_0-logloss:0.00626
# [46]	validation_0-logloss:0.00626
# [47]	validation_0-logloss:0.00626
# [48]	validation_0-logloss:0.00626
# [49]	validation_0-logloss:0.00626
# [50]	validation_0-logloss:0.00626
# [51]	validation_0-logloss:0.00626
# [52]	validation_0-logloss:0.00626
# [53]	validation_0-logloss:0.00626
# Stopping. Best iteration:
# [43]	validation_0-logloss:0.00626
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=100, min_child_weight=20, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# model
print ('model', model)
print('Is xgboost.core.Booster object ',model.get_booster())
importance_debug = get_score_debug(model.get_booster())
print ('feature importance_debug',importance_debug)
# Out:
# model XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=100, min_child_weight=20, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# Is xgboost.core.Booster object  <xgboost.core.Booster object at 0x116815a90>
# what is fucking problem
# trees <class 'list'> 54 ['0:leaf=-0.199734\n', '0:leaf=-0.18165\n', '0:leaf=-0.168059\n', '0:leaf=-0.157501\n', '0:leaf=-0.14909\n', '0:leaf=-0.142258\n', '0:leaf=-0.136619\n', '0:leaf=-0.131906\n', '0:leaf=-0.127924\n', '0:leaf=-0.124529\n', '0:leaf=-0.121612\n', '0:leaf=-0.119089\n', '0:leaf=-0.116894\n', '0:leaf=-0.114974\n', '0:leaf=-0.113287\n', '0:leaf=-0.111798\n', '0:leaf=-0.110479\n', '0:leaf=-0.109305\n', '0:leaf=-0.108257\n', '0:leaf=-0.107317\n', '0:leaf=-0.106472\n', '0:leaf=-0.105708\n', '0:leaf=-0.105015\n', '0:leaf=-0.104384\n', '0:leaf=-0.103805\n', '0:leaf=-0.103272\n', '0:leaf=-0.102778\n', '0:leaf=-0.102317\n', '0:leaf=-0.101884\n', '0:leaf=-0.101474\n', '0:leaf=-0.101082\n', '0:leaf=-0.100704\n', '0:leaf=-0.100337\n', '0:leaf=-0.0999758\n', '0:leaf=-0.0996178\n', '0:leaf=-0.0992594\n', '0:leaf=-0.0988973\n', '0:leaf=-0.0985284\n', '0:leaf=-0.0981494\n', '0:leaf=-0.0977574\n', '0:leaf=-0.0973492\n', '0:leaf=-0.0969219\n', '0:leaf=-0.0964724\n', '0:leaf=-0.0959977\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n', '0:leaf=0\n']
# tree 0:leaf=-0.199734
#
# line 0:leaf=-0.199734
# arr ['0:leaf=-0.199734'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.18165
#
# line 0:leaf=-0.18165
# arr ['0:leaf=-0.18165'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.168059
#
# line 0:leaf=-0.168059
# arr ['0:leaf=-0.168059'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.157501
#
# line 0:leaf=-0.157501
# arr ['0:leaf=-0.157501'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.14909
#
# line 0:leaf=-0.14909
# arr ['0:leaf=-0.14909'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.142258
#
# line 0:leaf=-0.142258
# arr ['0:leaf=-0.142258'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.136619
#
# line 0:leaf=-0.136619
# arr ['0:leaf=-0.136619'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.131906
#
# line 0:leaf=-0.131906
# arr ['0:leaf=-0.131906'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.127924
#
# line 0:leaf=-0.127924
# arr ['0:leaf=-0.127924'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.124529
#
# line 0:leaf=-0.124529
# arr ['0:leaf=-0.124529'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.121612
#
# line 0:leaf=-0.121612
# arr ['0:leaf=-0.121612'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.119089
#
# line 0:leaf=-0.119089
# arr ['0:leaf=-0.119089'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.116894
#
# line 0:leaf=-0.116894
# arr ['0:leaf=-0.116894'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.114974
#
# line 0:leaf=-0.114974
# arr ['0:leaf=-0.114974'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.113287
#
# line 0:leaf=-0.113287
# arr ['0:leaf=-0.113287'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.111798
#
# line 0:leaf=-0.111798
# arr ['0:leaf=-0.111798'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.110479
#
# line 0:leaf=-0.110479
# arr ['0:leaf=-0.110479'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.109305
#
# line 0:leaf=-0.109305
# arr ['0:leaf=-0.109305'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.108257
#
# line 0:leaf=-0.108257
# arr ['0:leaf=-0.108257'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.107317
#
# line 0:leaf=-0.107317
# arr ['0:leaf=-0.107317'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.106472
#
# line 0:leaf=-0.106472
# arr ['0:leaf=-0.106472'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.105708
#
# line 0:leaf=-0.105708
# arr ['0:leaf=-0.105708'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.105015
#
# line 0:leaf=-0.105015
# arr ['0:leaf=-0.105015'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.104384
#
# line 0:leaf=-0.104384
# arr ['0:leaf=-0.104384'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.103805
#
# line 0:leaf=-0.103805
# arr ['0:leaf=-0.103805'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.103272
#
# line 0:leaf=-0.103272
# arr ['0:leaf=-0.103272'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.102778
#
# line 0:leaf=-0.102778
# arr ['0:leaf=-0.102778'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.102317
#
# line 0:leaf=-0.102317
# arr ['0:leaf=-0.102317'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.101884
#
# line 0:leaf=-0.101884
# arr ['0:leaf=-0.101884'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.101474
#
# line 0:leaf=-0.101474
# arr ['0:leaf=-0.101474'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.101082
#
# line 0:leaf=-0.101082
# arr ['0:leaf=-0.101082'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.100704
#
# line 0:leaf=-0.100704
# arr ['0:leaf=-0.100704'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.100337
#
# line 0:leaf=-0.100337
# arr ['0:leaf=-0.100337'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0999758
#
# line 0:leaf=-0.0999758
# arr ['0:leaf=-0.0999758'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0996178
#
# line 0:leaf=-0.0996178
# arr ['0:leaf=-0.0996178'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0992594
#
# line 0:leaf=-0.0992594
# arr ['0:leaf=-0.0992594'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0988973
#
# line 0:leaf=-0.0988973
# arr ['0:leaf=-0.0988973'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0985284
#
# line 0:leaf=-0.0985284
# arr ['0:leaf=-0.0985284'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0981494
#
# line 0:leaf=-0.0981494
# arr ['0:leaf=-0.0981494'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0977574
#
# line 0:leaf=-0.0977574
# arr ['0:leaf=-0.0977574'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0973492
#
# line 0:leaf=-0.0973492
# arr ['0:leaf=-0.0973492'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0969219
#
# line 0:leaf=-0.0969219
# arr ['0:leaf=-0.0969219'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0964724
#
# line 0:leaf=-0.0964724
# arr ['0:leaf=-0.0964724'] 1
# line
# arr [''] 1
# tree 0:leaf=-0.0959977
#
# line 0:leaf=-0.0959977
# arr ['0:leaf=-0.0959977'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# tree 0:leaf=0
#
# line 0:leaf=0
# arr ['0:leaf=0'] 1
# line
# arr [''] 1
# feature importance_debug {}

# %%
'''
問題在於我的樹都沒有展開like the below:
    tree 0:[f1<101.5] yes=1,no=2,missing=1
	1:[f0<11.5] yes=3,no=4,missing=3
		3:[f6<1.181] yes=7,no=8,missing=7
			7:leaf=-0.113265
			8:leaf=0.0195017
		4:leaf=0.0302529
	2:[f5<26.45] yes=5,no=6,missing=5
		5:[f7<49.5] yes=9,no=10,missing=9
			9:leaf=-0.115234
			10:leaf=0.0190025
		6:[f6<0.528] yes=11,no=12,missing=11
			11:leaf=-0.0131559
			12:leaf=0.0676579
'''

# %%
for i in range(3):
    if i == 1:
        continue
        # To loop, the below code will not be executed
    print(i)
# Out:
# 0
# 2
